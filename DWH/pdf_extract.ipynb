# %% [markdown]
# <h1><b>EXTRACK FILE PDF</b></h1>

# %%
# !pip install PyPDF2 openpyxl pdfplumber
# Out:
# Collecting PyPDF2
#   Using cached pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: openpyxl in c:\users\msi katana\appdata\local\programs\python\python312\lib\site-packages (3.1.2)
# Collecting pdfplumber
#   Using cached pdfplumber-0.11.4-py3-none-any.whl.metadata (41 kB)
# Requirement already satisfied: et-xmlfile in c:\users\msi katana\appdata\local\programs\python\python312\lib\site-packages (from openpyxl) (1.1.0)
# Collecting pdfminer.six==20231228 (from pdfplumber)
#   Using cached pdfminer.six-20231228-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Pillow>=9.1 in c:\users\msi katana\appdata\local\programs\python\python312\lib\site-packages (from pdfplumber) (10.2.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Using cached pypdfium2-4.30.0-py3-none-win_amd64.whl.metadata (48 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\msi katana\appdata\local\programs\python\python312\lib\site-packages (from pdfminer.six==20231228->pdfplumber) (3.3.2)
# Collecting cryptography>=36.0.0 (from pdfminer.six==20231228->pdfplumber)
#   Using cached cryptography-44.0.0-cp39-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting cffi>=1.12 (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber)
#   Downloading cffi-1.17.1-cp312-cp312-win_amd64.whl.metadata (1.6 kB)
# Collecting pycparser (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber)
#   Downloading pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Using cached pypdf2-3.0.1-py3-none-any.whl (232 kB)
# Using cached pdfplumber-0.11.4-py3-none-any.whl (59 kB)
# Using cached pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
# Using cached pypdfium2-4.30.0-py3-none-win_amd64.whl (2.9 MB)
# Using cached cryptography-44.0.0-cp39-abi3-win_amd64.whl (3.2 MB)
# Downloading cffi-1.17.1-cp312-cp312-win_amd64.whl (181 kB)
# Downloading pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: pypdfium2, PyPDF2, pycparser, cffi, cryptography, pdfminer.six, pdfplumber
# Successfully installed PyPDF2-3.0.1 cffi-1.17.1 cryptography-44.0.0 pdfminer.six-20231228 pdfplumber-0.11.4 pycparser-2.22 pypdfium2-4.30.0

# %%
import os
import re
import time
import pandas as pd
from PyPDF2 import PdfReader
from tabulate import tabulate
import pdfplumber
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_rows', None)  # Tampilkan semua baris
pd.set_option('display.max_columns', None)  # Tampilkan semua kolom

# %%
# Daftar bulan untuk pencocokan
bulan_list_id = [
    "Januari", "Februari", "Maret", "April", "Mei", "Juni",
    "Juli", "Agustus", "September", "Oktober", "November", "Desember"
]

bulan_list_en = [
    "January", "February", "March", "April", "May", "June",
    "July", "August", "September", "October", "November", "December"
]

# Fungsi mengambil teks dari halaman pertama file PDF
def extract_first_pages_pdf(pdf_path):
    with pdfplumber.open(pdf_path) as pdf:
        first_page = pdf.pages[0]
        text = first_page.extract_text()
    return text

# Fungsi mengambil teks dari beberapa halaman file PDF
def extract_text_from_pages(pdf_path, start_page=1, end_page=None):
    try:
        reader = PdfReader(pdf_path)
        text_content = ""
        total_pages = len(reader.pages)

        if end_page is None or end_page > total_pages:
            end_page = total_pages

        for page_num in range(start_page - 1, end_page):
            page = reader.pages[page_num]
            text_content += page.extract_text() + "\n"
        return text_content
    except Exception as e:
        print(f"Error reading PDF {pdf_path}: {str(e)}")
        return None

# Fungsi untuk mengekstrak tabel dari teks
def extract_table_data(text_content, filename):
    lines = text_content.split('\n')

    items, values, notes, file_sources = [], [], [], []
    number_pattern = r'\(?[\d,.]+\)?'
    notes_pattern_1 = r'\d+[a-zA-Z](?:,\s?[a-zA-Z\d]+)*'
    notes_pattern_2 = r'\b\d{1,2}(?:,\s?\d{1,2})*\b'

    for line in lines:
        line = line.strip()
        number_match = re.search(number_pattern, line)
        notes_match_1 = re.search(notes_pattern_1, line)
        notes_match_2 = re.search(notes_pattern_2, line)

        if number_match:
            item = re.sub(number_pattern, '', line)
            item = re.sub(notes_pattern_1, '', item)
            item = re.sub(notes_pattern_2, '', item)
            item = re.sub(r'\s+', ' ', item).strip()
            item = re.sub(r'\(\s*\).*', '', item).strip()

            numbers = re.findall(number_pattern, line)
            value = numbers[0] if numbers else ""

            if notes_match_1:
                note = notes_match_1.group()
            elif notes_match_2:
                note = notes_match_2.group()
            else:
                note = ""

            if value.startswith('(') and value.endswith(')'):
                value = '-' + value[1:-1].replace('.', '').replace(',', '')
            else:
                value = value.replace('.', '').replace(',', '')

            items.append(item)
            values.append(value)
            notes.append(note)
            file_sources.append(filename)

    df = pd.DataFrame({
        'Item': items,
        'Notes': notes,
        'Value': values,
        'Source_File': file_sources
    })
    return df

# Fungsi untuk mengekstrak nama perusahaan, bulan, dan tahun
def find_company_and_month_year(text):
    company_pattern = re.compile(r"(PT\s[\w\s]+,\s?Tbk|PT\s[\w\s]+Tbk)", re.IGNORECASE)
    company_match = company_pattern.search(text)

    months_years = []
    for bulan in bulan_list_id + bulan_list_en:
        pattern = re.compile(rf"(\b{bulan}\b)\s(\d{{4}})", re.IGNORECASE)
        matches = pattern.findall(text)
        for match in matches:
            month, year = match
            months_years.append((month.strip(), int(year)))

    company_name = company_match.group(1) if company_match else "Tidak ditemukan"
    return company_name, months_years

# Fungsi untuk memproses semua file PDF dalam folder
def process_pdf_folder(folder_path, table_start_page=1, table_end_page=8):
    table_dfs = []
    info_dfs = []
    pdf_files = [f for f in os.listdir(folder_path) if f.lower().endswith('.pdf')]

    if not pdf_files:
        print(f"No PDF files found in {folder_path}")
        return None

    for pdf_file in pdf_files:
        pdf_path = os.path.join(folder_path, pdf_file)
        print(f"Processing {pdf_file}...")

        first_page_text = extract_first_pages_pdf(pdf_path)
        if first_page_text:
            company_name, months_years = find_company_and_month_year(first_page_text)

            if months_years:
                latest_month, latest_year = months_years[-1]
                info_df = pd.DataFrame({
                    'Nama Perusahaan': [company_name],
                    'Bulan': [latest_month],
                    'Tahun': [latest_year],
                    'Source_File': [pdf_file]
                })
                info_dfs.append(info_df)

        table_text = extract_text_from_pages(pdf_path, table_start_page, table_end_page)
        if table_text:
            table_df = extract_table_data(table_text, pdf_file)
            if not table_df.empty:
                table_dfs.append(table_df)

    if table_dfs and info_dfs:
        combined_table_df = pd.concat(table_dfs, ignore_index=True)
        combined_info_df = pd.concat(info_dfs, ignore_index=True)

        merged_df = pd.merge(combined_info_df, combined_table_df, on='Source_File', how='left')
        return merged_df
    else:
        print("No data was extracted from any PDF files")
        return None

# Main function
if __name__ == "__main__":
    folder_path = 'C:/TI-Dwika/Semester 7/Pangkalan Data/file_pdf'
    merged_pdf = process_pdf_folder(folder_path)

    if merged_pdf is not None:
        print("\nExtracted Data:")
        print(tabulate(merged_pdf, headers='keys', tablefmt='grid', showindex=False))
    else:
        print("No data extracted.")
# Out:
# Processing AGAR TW 2 KONSOL 2024.pdf...
# Processing FKS Food Sejahtera TBK billingual 31 Maret 2024.pdf...
# Processing Lapkeu ABBA 31 Mar 2024.pdf...
# Processing LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf...
#
# Extracted Data:
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | Nama Perusahaan                  | Bulan    |   Tahun | Source_File                                         | Item                                                                                           | Notes          | Value         |
# +==================================+==========+=========+=====================================================+================================================================================================+================+===============+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | PT ASIA SEJAHTERA MINA Tbk                                                                     |                |               |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | JUNI /                                                                                         | 30             | 30            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | JUNE                                                                                           | 30             | 30            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | PT ASIA SEJAHTERA MINA TBK                                                                     |                |               |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | DAFTAR ISI PT ASIA SEJAHTERA MINA TBK                                                          |                |               |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Juni dan Desember                                                                              | 30             | 30            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Juni dan June and December and for                                                             | 30             | 30            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | the six month period ended June                                                                | 30             | 30            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | and                                                                                            | 3              | 202           |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           |                                                                                                | 1              | 1             |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Kompehensif Lain Statement for Profit or Loss and Other                                        | 3              | 3             |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Laporan Perubahan Ekuitas Statements of Changes in Equity                                      | 4              | 4             |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Laporan Arus Kas Statements of Cash Flows                                                      | 5              | 5             |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Catatan atas Laporan Keuangan Notes to Financial Statements                                    | 6              | 6             |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | PT ASIA SEJAHTERA MINA TBK                                                                     |                |               |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | JUNI (TIDAK DIAUDIT) PT ASIA SEJAHTERA MINA TBK                                                | 30             | 30            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | JUNE (UNAUDITED)                                                                               | 30             | 30            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           |                                                                                                | 1              | 1             |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Catatan/ Juni / Desember /                                                                     | 30             | 30            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Notes June December                                                                            | 30             | 30            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Kas dan setara kas Cash and equivalents                                                        | 4              | 4             |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Kas yang di batasi penggunaannya Restricted cash                                               | 5              | 5             |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | pihak ketiga third parties                                                                     | 6              | 6             |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Piutang lain-lain Other receivables                                                            | 7              | 7             |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Pihak ketiga Third parties                                                                     | 8              | 8500000       |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Persediaan Inventories                                                                         | 8              | 8             |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Pajak dibayar dimuka a Prepaid taxes                                                           | 29a            | 29            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Uang muka pembelian Advance payments                                                           | 9              | 9             |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Biaya dibayar di muka Prepaid expenses                                                         | 10             | 10            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Jumlah Aset Lancar Total Current Assets                                                        |                | 143028054880  |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | akumulasi penyusutan sebesar accumulated depreciation of                                       |                |               |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Rp pada Rp                                                                                     | 21             | 21102003830   |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Juni dan in June and                                                                           | 30             | 30            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Rp pada Rp                                                                                     | 19             | 19956724738   |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Desember in December                                                                           | 31             | 31            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Aset lain-lain Other asset                                                                     | 12             | 12            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Aset pajak tangguhan d Prepaid tax                                                             | 29d            | 29            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Goodwill Goodwill                                                                              | 13             | 13            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Jumlah Aset Tidak Lancar Total Non Current Assets                                              | 54             | 54542236450   |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | JUMLAH ASET TOTAL ASSETS                                                                       |                | 197570291330  |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | PT ASIA SEJAHTERA MINA TBK                                                                     |                |               |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | JUNI (TIDAK DIAUDIT) - LANJUTAN PT ASIA SEJAHTERA MINA TBK                                     | 30             | 30            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | JUNE (UNAUDITED) - CONTINUED                                                                   | 30             | 30            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           |                                                                                                | 2              | 2             |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Catatan/ Juni / Desember /                                                                     | 30             | 30            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Notes June December                                                                            | 30             | 30            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Utang usaha Trade account payable                                                              | 14             | 14            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Pihak ketiga Third parties                                                                     | 13             | 13596051519   |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Utang lain-lain Others payable                                                                 | 15             | 15            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Beban akrual Accrued expense                                                                   | 16             | 16            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Uang titipan Deposit payabe                                                                    | 17             | 17            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Utang pajak b Taxes payable                                                                    | 29b            | 29            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Utang bank Bank loan                                                                           | 18             | 18            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | yang jatuh tempo dalam satu tahun lease payables                                               | 19             | 19            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Jumlah Liabilitas Jangka Pendek Total Short Term Liabilities                                   | 84             | 84940338169   |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | tempo dalam satu tahun current maturities                                                      | 19             | 19            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Liabilitas imbalan kerja Employee benefits obligation                                          | 20             | 20            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Jumlah Liabilitas Jangka Panjang Total Non-Current Liabilities                                 | 6              | 6904309760    |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Jumlah Liabilitas Total Liabilities                                                            | 91             | 91844647929   |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Rp per lembar saham Rp of per share                                                            |                | 100           |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Modal dasar lembar Authorized shares                                                           | 3              | 3000000000    |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | penuh - saham shares                                                                           | 1              | 1000000000    |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | pengampunan pajak tax amnesty                                                                  | 2              | 2000000000    |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Tambahan modal disetor Additional paid-in capital                                              | 22             | 22            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Penghasilan komprehensif lain Other comprehensive income                                       | 23             | 23            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Laba Gain                                                                                      | 1              | -182041469    |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Jumlah Ekuitas Total Equity                                                                    |                | 105725714175  |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Kepentingan non-pengendali Non-controlling interest                                            | 70             | -70774        |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | JUMLAH EKUITAS TOTAL EQUITY                                                                    |                | 105725643401  |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | JUMLAH KEWAJIBAN DAN EKUITAS AND EQUITY                                                        |                | 197570291330  |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | PT ASIA SEJAHTERA MINA TBK                                                                     |                |               |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | PADA JUNI DAN (TIDAK DIAUDIT) PT ASIA SEJAHTERA MINA TBK                                       | 3              | 3             |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | JUNE AND (UNAUDITED)                                                                           | 30             | 30            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           |                                                                                                | 3              | 3             |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Catatan/ Juni / Juni /                                                                         | 30             | 30            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Notes June June                                                                                | 30             | 30            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | PENJUALAN BERSIH NET SALES                                                                     | 24             | 24            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | BEBAN POKOK PENJUALAN COST OF GOODS SOLD                                                       | 25             | 25            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | LABA KOTOR GROSS PROFIT                                                                        | 15             | 15107149705   |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Beban usaha Operating Expense                                                                  | 26             | 26            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Pendapatan lain-lain Other income                                                              | 27             | 27            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Beban lain-lain Others Expense                                                                 | 28             | 28            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | JUMLAH BEBAN USAHA TOTAL OPERATING EXPENSES                                                    | 16             | -16334151439  |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | PAJAK PENGHASILAN INCOME TAX                                                                   | 1              | -1227001734   |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | BEBAN PAJAK PENGHASILAN c INCOME TAX EXPENSES                                                  | 29c            | 29            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | LABA (RUGI) BERSIH NET GAIN (LOSS)                                                             | 1              | -1240129354   |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | KOMPREHENSIF GAIN (LOSS)                                                                       | 1              | -1240129354   |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Pemilik entitas induk Owner of the parent                                                      | 1              | -1240078338   |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Kepentingan non pengendali Non-controlling interest                                            | 51             | -51016        |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | TAHUN BERJALAN FOR THE YEAR                                                                    | 1              | -1240129354   |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Pemilik entitas induk Owner of the parent                                                      | 1              | -1240078338   |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | Kepentingan non pengendali Non-controlling interest                                            | 51             | -51016        |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | KOMPREHENSIF TAHUN BERJALAN (LOSS) FOR THE YEAR                                                | 1              | -1240129354   |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | LABA (LOSS) PER LEMBAR SAHAM GAIN (LOSS) PER SHARE                                             | 0              | -099936       |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | PT ASIA SEJAHTERA MINA TBK                                                                     |                |               |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | UNTUK PERIODE ENAM BULAN YANG BERAKHIR JUNI PT ASIA SEJAHTERA MINA TBK                         | 30             | 30            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA, Tbk      | JUNI     |    2024 | AGAR TW 2 KONSOL 2024.pdf                           | FOR THE SIX MONTHS PERIOD ENDED JUNE                                                           | 30             | 30            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# ...
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | PENJUALAN a e l SALES                                                                          | 2a, 2e, 2l, 21 | 13168704267   |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | PENJUALAN a l COST OF SALES                                                                    | 2a, 2          | -7153361175   |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | LABA KOTOR GROSS PROFIT                                                                        | 6              | 6015343092    |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | dan umum a l General and                                                                       | 2a, 2          | -1101107489   |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | selisih kurs ) a l Gain (loss) on foreign                                                      | 2a, 2l         | (1048386973   |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | operasional lainnya a e l Other operational income                                             | 2a, 2e, 2l, 24 | 30287750      |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | terealisasi                                                                                    | 16             | 1671724       |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | a                                                                                              | 2a, 8          | 2             |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | Unrealized gain (loss)                                                                         | 16             | 1671724       |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | operasional lainnya a l ) Other operational revenue                                            | 2a, 2l         | 62466060      |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | LABA OPERASI INCOME FROM                                                                       | 3              | 3975319689    |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | Pendapatan keuangan a l Financial income                                                       | 2a, 2          | 14107546      |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | Beban keuangan ) a l ) Financial expenses                                                      | 2a, 2          | (445798600    |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | PENGHASILAN INCOME BEFORE                                                                      | 3              | 3543628635    |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | penghasilan kini a l nB Current Income tax                                                     | 2a, 2l, 2n,16B | -777612118    |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | tangguhan a n                                                                                  | 2a, 2n         | 26623874      |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | c Deferred income tax                                                                          | 16c            | 16            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | TAHUN BERJALAN CURRENT YEAR NET                                                                | 2              | 2792640391    |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | in Indonesian language                                                                         |                |               |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | MARET DAN (TIDAK DIAUDIT) MARCH AND (UNAUDITED)                                                | 31             | 31            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | (Disajikan dalam Rupiah kecuali dinyatakan lain) (Expressed in Rupiah unless otherwise stated) |                |               |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | secara keseluruhan The accompanying notes to the financial statements form                     |                |               |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | Halaman - - Page                                                                               | 4              | 4             |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | Maret/                                                                                         | 31             | 31            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | March Catatan/                                                                                 |                | 2024          |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | Maret/                                                                                         | 31             | 31            |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | March                                                                                          |                | 2023          |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | TAHUN BERJALAN CURRENT YEAR NET                                                                | 2              | 2792640391    |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | pasti a m Remeasurement of                                                                     | 2a, 2m, 1      | -34637375     |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | pasti a n c The effect of deferred tax                                                         | 2a, 2n, 1      | 7620223       |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | LAIN – BERSIH OTHER                                                                            | 27             | -27017152     |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | TAHUN BERJALAN TOTAL CURRENT                                                                   | 2              | 2765623239    |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | DESEMBER |    2023 | LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf | LABA PER SAHAM r EARNING PER SHARE                                                             | 2r, 27         | 2             |
# +----------------------------------+----------+---------+-----------------------------------------------------+------------------------------------------------------------------------------------------------+----------------+---------------+

# %% [markdown]
# <h2><b>EKSTRAK NOTES</b></h2>

# %%
def extract_text_from_pdf(pdf_path, start_page=1, end_page=None):
    """
    Extract text content from a PDF file, limited to specific page range.
    """
    try:
        reader = PdfReader(pdf_path)
        text_content = ""
        total_pages = len(reader.pages)

        # Adjust end_page if it's not provided or exceeds total pages
        if end_page is None or end_page > total_pages:
            end_page = total_pages

        # Extract text from the specified page range
        for page_num in range(start_page - 1, end_page):
            page = reader.pages[page_num]
            text_content += page.extract_text() + "\n"
        return text_content
    except Exception as e:
        print(f"Error reading PDF {pdf_path}: {str(e)}")
        return None


def extract_table_data(text_content, filename):
    """
    Extract table data from text content with notes and values.
    Handles different table formats where notes and values might be in different positions.
    """
    # Split content into lines
    lines = text_content.split('\n')

    # Initialize lists to store extracted data
    items = []
    values = []
    notes = []
    file_sources = []  # To track which file each row came from

    # Regular expressions for matching
    number_pattern = r'\(?[\d,.]+\)?'  # Matches numbers with 6 or more digits

    # First notes pattern: Matches patterns like 2f, 2v, or 2v,2g
    notes_pattern_1 = r'\d+[a-zA-Z](?:,\s?[a-zA-Z\d]+)*'  # Matches patterns like 2v, 2g, 3f, or 2v,2g

    # Second notes pattern: Matches just numbers (like 22)
    notes_pattern_2 = r'\b\d{1,2}(?:,\s?\d{1,2})*\b'

    for line in lines:
        # Clean the line
        line = line.strip()

        # Try to identify components
        number_match = re.search(number_pattern, line)
        notes_match_1 = re.search(notes_pattern_1, line)
        notes_match_2 = re.search(notes_pattern_2, line)

        if number_match:
            # Extract the item name by removing numbers and notes
            item = re.sub(number_pattern, '', line)  # Remove numbers from item
            item = re.sub(notes_pattern_1, '', item)  # Remove notes from item
            item = re.sub(notes_pattern_2, '', item)  # Remove additional notes
            item = re.sub(r'\s+', ' ', item).strip()  # Replace multiple spaces with a single space

            # Remove empty parentheses and remaining text after them
            item = re.sub(r'\(\s*\).*', '', item).strip()

            # Remove single or double letters and all remaining text after them
            item = re.sub(r'\s[a-zA-Z]{1,2}\s.*', '', item).strip()

            # # Remove remaining words if they start with an uppercase letter
            # item = re.sub(r'\s[A-Z][a-zA-Z]*.*', '', item).strip()

            # Remove remaining words if they start with an uppercase letter, but not all caps
            item = re.sub(r'\s([A-Z][a-z][a-zA-Z]*)\b.*', '', item).strip()

            numbers = re.findall(number_pattern, line)
            if len(numbers) > 1:
                # General case: pick the second number, or use any logic to decide which number to take
                value = numbers[1]  # Take the second number (can be adjusted)
            elif len(numbers) == 1:
                value = numbers[0]
            else:
                # If no numbers found, return an empty string
                value = " "

            # Extract value
            # value = number_match.group()
            
            # Use the first notes pattern if it matches (allows comma-separated notes)
            if notes_match_1:
                note = notes_match_1.group()
            # Only use the second notes pattern if the first one didn't match
            elif notes_match_2 and not notes_match_1:
                note = notes_match_2.group()
            else:
                note = ""  # Default case if no notes are found

            # Directly append to lists without any additional condition
            values.append(value)
            notes.append(note)

            # Only include if we have all components and it's not a total
            if item and not item.lower().startswith('total'):
                items.append(item)
                file_sources.append(filename)  # Add filename to track source

            # Ensure lists remain the same length by filling any missing values
            while len(items) < len(values):
                items.append("")
            while len(notes) < len(values):
                notes.append("")
            while len(file_sources) < len(values):
                file_sources.append("")

    # Create DataFrame
    df = pd.DataFrame({
        'Item': items,
        'Notes': notes,
        'Value': values,
        'Source_File': file_sources
    })
    
    return df


# import re
# import pandas as pd

# def extract_table_data(text_content, filename):
#     """
#     Extract table data from text content with notes and values.
#     Handles different table formats where notes and values might be in different positions.
#     """
#     # Split content into lines
#     lines = text_content.split('\n')

#     # Initialize lists to store extracted data
#     items = []
#     values = []
#     notes = []
#     file_sources = []  # To track which file each row came from

#     # Regular expressions for matching
#     number_pattern = r'[\d,.]+'  # Matches numbers with commas and periods

#     # First notes pattern: Matches patterns like 2f, 2v, or 2v,2g
#     notes_pattern_1 = r'\d+[a-zA-Z](?:,\s?[a-zA-Z\d]+)*'  # Matches patterns like 2v, 2g, 3f, or 2v,2g

#     # Second notes pattern: Matches just numbers (like 22)
#     notes_pattern_2 = r'\b\d{1,2}(?:,\s?\d{1,2})*\b'

#     for line in lines:
#         # Clean the line
#         line = line.strip()

#         # Try to identify components
#         notes_match_1 = re.search(notes_pattern_1, line)
#         notes_match_2 = re.search(notes_pattern_2, line)

#         # Extract numbers from the line
#         numbers = re.findall(number_pattern, line)
        
#         # Default value for note and value
#         note = ""
#         value = ""

#         # Case 1: If notes pattern 1 matches (like 29d, 2f)
#         if notes_match_1:
#             note = notes_match_1.group()  # Capture the notes (e.g., '29d')
#             # Find numbers after the note
#             notes_end_pos = line.find(note) + len(note)
#             line_after_notes = line[notes_end_pos:].strip()
#             numbers_after_notes = re.findall(number_pattern, line_after_notes)
#             value = numbers_after_notes[0] if numbers_after_notes else numbers[0]  # Value after notes, or first number

#         # Case 2: If notes pattern 2 matches (like 22, 12)
#         elif notes_match_2:
#             note = notes_match_2.group()  # Capture the notes (e.g., '22')
#             # Take the first number as the value
#             value = numbers[0] if numbers else ""

#         # Case 3: If no notes pattern matches, take the first number as the value
#         elif numbers:
#             value = numbers[0]

#         # Clean the item name by removing numbers and notes
#         item = re.sub(number_pattern, '', line)  # Remove all numbers from item
#         item = re.sub(f"{note}$", '', item).strip()  # Remove notes from item
#         item = re.sub(r'\s+', ' ', item).strip()  # Replace multiple spaces with a single space

#         # Clean up further
#         item = re.sub(r'\(\s*\).*', '', item).strip()  # Remove empty parentheses and text after them
#         item = re.sub(r'\s[a-zA-Z]{1,2}\s.*', '', item).strip()  # Remove single/double letters and text after them
#         item = re.sub(r'\s([A-Z][a-z][a-zA-Z]*)\b.*', '', item).strip()  # Remove words starting with uppercase letters

#         # Append the extracted values
#         values.append(value)
#         notes.append(note)

#         # Only include if we have all components and it's not a total
#         if item and not item.lower().startswith('total'):
#             items.append(item)
#             file_sources.append(filename)  # Add filename to track source

#         # Ensure lists remain the same length by filling any missing values
#         while len(items) < len(values):
#             items.append("")
#         while len(notes) < len(values):
#             notes.append("")
#         while len(file_sources) < len(values):
#             file_sources.append("")

#     # Create DataFrame
#     df = pd.DataFrame({
#         'Item': items,
#         'Notes': notes,
#         'Value': values,
#         'Source_File': file_sources
#     })
    
#     return df




def process_folder(folder_path, start_page=1, end_page=8):
    """
    Process all PDF files in a folder and combine results, limited to specific page range.
    """
    # List to store all DataFrames
    all_dfs = []

    # Get all PDF files in the folder
    pdf_files = [f for f in os.listdir(folder_path) if f.lower().endswith('.pdf')]

    if not pdf_files:
        print(f"No PDF files found in {folder_path}")
        return None

    # Process each PDF file
    for pdf_file in pdf_files:
        print(f"Processing {pdf_file}...")
        pdf_path = os.path.join(folder_path, pdf_file)

        # Extract text from PDF
        text_content = extract_text_from_pdf(pdf_path, start_page, end_page)

        if text_content:
            # Process the content
            df = extract_table_data(text_content, pdf_file)
            if not df.empty:
                all_dfs.append(df)
            else:
                print(f"No relevant data found in {pdf_file}")

    if all_dfs:
        # Combine all DataFrames
        combined_df = pd.concat(all_dfs, ignore_index=True)

        # Clean up the DataFrame
        combined_df['Item'] = combined_df['Item'].str.strip()
        combined_df['Notes'] = combined_df['Notes'].str.strip()
        # combined_df['Value'] = combined_df['Value'].str.strip()

        return combined_df
    else:
        print("No data was extracted from any PDF files")
        return None


def main(folder_path, start_page=1, end_page=8):
    """
    Main function to process folder and save results.
    """
    # Process the folder with specific page range
    df = process_folder(folder_path, start_page, end_page)

    if df is not None:
        # Display summary
        print(f"\nTotal rows extracted: {len(df)}")
        print(f"Files processed: {df['Source_File'].nunique()}")

        # Display sample of results
        print("\nSample of extracted data:")
        print(df.to_string())

    return df

# Example usage
if __name__ == "__main__":
    # Replace with your folder path
    folder_path = "C:/TI-Dwika/Semester 7/Pangkalan Data/file_pdf"
    start_page = 1
    end_page = 8
    df_data = main(folder_path, start_page, end_page)
# Out:
# Processing AGAR TW 2 KONSOL 2024.pdf...
# Processing FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf...
# Processing Lapkeu ABBA 31 Mar 2024 (1).pdf...
# Processing LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf...
#
# Total rows extracted: 539
# Files processed: 5
#
# Sample of extracted data:
#                                                                     Item           Notes                Value                                           Source_File
# 0                                                 PT ASIA SEJAHTERA MINA                                    ,                             AGAR TW 2 KONSOL 2024.pdf
# 1                                                                 JUNI /              30                 2024                             AGAR TW 2 KONSOL 2024.pdf
# 2                                                                   JUNE              30                  202                             AGAR TW 2 KONSOL 2024.pdf
# 3                                             PT ASIA SEJAHTERA MINA TBK                                    ,                             AGAR TW 2 KONSOL 2024.pdf
# 4                                                             DAFTAR ISI                                    ,                             AGAR TW 2 KONSOL 2024.pdf
# 5                                                               Juni dan              30                 2024                             AGAR TW 2 KONSOL 2024.pdf
# 6                                                               Juni dan              30                 2024                             AGAR TW 2 KONSOL 2024.pdf
# 7                                             the six month period ended              30                  202                             AGAR TW 2 KONSOL 2024.pdf
# 8                                                                    and               3                    3                             AGAR TW 2 KONSOL 2024.pdf
# 9                                                                                      1                    1
# 10                                                           Kompehensif               3                    3                             AGAR TW 2 KONSOL 2024.pdf
# 11                                                               Laporan               4                    4                             AGAR TW 2 KONSOL 2024.pdf
# 12                                                               Laporan               5                    5                             AGAR TW 2 KONSOL 2024.pdf
# 13                                                          Catatan atas               6                    6                             AGAR TW 2 KONSOL 2024.pdf
# 14                                            PT ASIA SEJAHTERA MINA TBK                                    ,                             AGAR TW 2 KONSOL 2024.pdf
# 15                                                  JUNI (TIDAK DIAUDIT)              30                 2024                             AGAR TW 2 KONSOL 2024.pdf
# 16                                                      JUNE (UNAUDITED)              30                  202                             AGAR TW 2 KONSOL 2024.pdf
# 17                                                                                     1                    1
# 18                                                              Catatan/              30                 2024                             AGAR TW 2 KONSOL 2024.pdf
# 19                                                                 Notes              30                 2024                             AGAR TW 2 KONSOL 2024.pdf
# 20                                                    Kas dan setara kas               4       14.047.355.680                             AGAR TW 2 KONSOL 2024.pdf
# 21                                                              Kas yang               5        1.900.000.000                             AGAR TW 2 KONSOL 2024.pdf
# 22                                            pihak ketiga third parties               6       36.522.725.228                             AGAR TW 2 KONSOL 2024.pdf
# 23                                                     Piutang lain-lain               7                    7                             AGAR TW 2 KONSOL 2024.pdf
# 24                                                          Pihak ketiga               8            2.500.000                             AGAR TW 2 KONSOL 2024.pdf
# 25                                                            Persediaan               8       78.031.491.296                             AGAR TW 2 KONSOL 2024.pdf
# 26                                                  Pajak dibayar dimuka             29a        1.197.505.340                             AGAR TW 2 KONSOL 2024.pdf
# 27                                                   Uang muka pembelian               9       11.239.481.729                             AGAR TW 2 KONSOL 2024.pdf
# 28                                                         Biaya dibayar              10           80.995.607                             AGAR TW 2 KONSOL 2024.pdf
# 29                                                                Jumlah                      143.541.791.622                             AGAR TW 2 KONSOL 2024.pdf
# 30              akumulasi penyusutan sebesar accumulated depreciation of                                    ,                             AGAR TW 2 KONSOL 2024.pdf
# 31                                                               Rp pada              21       21,102,003,830                             AGAR TW 2 KONSOL 2024.pdf
# 32                                                              Juni dan              30                 2024                             AGAR TW 2 KONSOL 2024.pdf
# 33                                                               Rp pada              19       19,956,724,738                             AGAR TW 2 KONSOL 2024.pdf
# 34                                                              Desember              31                 2023                             AGAR TW 2 KONSOL 2024.pdf
# 35                                                        Aset lain-lain              12        2.189.288.648                             AGAR TW 2 KONSOL 2024.pdf
# 36                                                  Aset pajak tangguhan             29d        1.071.584.465                             AGAR TW 2 KONSOL 2024.pdf
# 37                                                              Goodwill              13        5.321.917.155                             AGAR TW 2 KONSOL 2024.pdf
# 38                                                                Jumlah              54       53.373.108.248                             AGAR TW 2 KONSOL 2024.pdf
# 39                                              JUMLAH ASET TOTAL ASSETS                      196.914.899.870                             AGAR TW 2 KONSOL 2024.pdf
# 40                                            PT ASIA SEJAHTERA MINA TBK                                    ,                             AGAR TW 2 KONSOL 2024.pdf
# 41                                       JUNI (TIDAK DIAUDIT) - LANJUTAN              30                 2024                             AGAR TW 2 KONSOL 2024.pdf
# 42                                          JUNE (UNAUDITED) - CONTINUED              30                    ,                             AGAR TW 2 KONSOL 2024.pdf
# 43                                                                                     2                    2
# 44                                                              Catatan/              30                 2024                             AGAR TW 2 KONSOL 2024.pdf
# 45                                                                 Notes              30                 2024                             AGAR TW 2 KONSOL 2024.pdf
# 46                                                           Utang usaha              14                   14                             AGAR TW 2 KONSOL 2024.pdf
# 47                                                          Pihak ketiga              13       13.638.407.079                             AGAR TW 2 KONSOL 2024.pdf
# 48                                                       Utang lain-lain              15          149.264.284                             AGAR TW 2 KONSOL 2024.pdf
# 49                                                          Beban akrual              16           86.238.167                             AGAR TW 2 KONSOL 2024.pdf
# 50                                                          Uang titipan              17        1.922.352.000                             AGAR TW 2 KONSOL 2024.pdf
# 51                                                           Utang pajak             29b          149.071.620                             AGAR TW 2 KONSOL 2024.pdf
# 52                                                            Utang bank              18        6.095.439.944                             AGAR TW 2 KONSOL 2024.pdf
# 53                      yang jatuh tempo dalam satu tahun lease payables              19       62.941.920.635                             AGAR TW 2 KONSOL 2024.pdf
# 54                                                                Jumlah              84       81.650.705.594                             AGAR TW 2 KONSOL 2024.pdf
# 55                             tempo dalam satu tahun current maturities              19        6.041.150.918                             AGAR TW 2 KONSOL 2024.pdf
# 56                                              Liabilitas imbalan kerja              20          863.158.842                             AGAR TW 2 KONSOL 2024.pdf
# 57                                                                Jumlah               6        8.298.421.520                             AGAR TW 2 KONSOL 2024.pdf
# 58                                                                Jumlah              91       89.949.127.114                             AGAR TW 2 KONSOL 2024.pdf
# 59                                                   Rp per lembar saham                                  100                             AGAR TW 2 KONSOL 2024.pdf
# 60                                                    Modal dasar lembar               3        3,000,000,000                             AGAR TW 2 KONSOL 2024.pdf
# 61                                                  penuh - saham shares               1                   21                             AGAR TW 2 KONSOL 2024.pdf
# 62                                         pengampunan pajak tax amnesty               2        2.000.000.000                             AGAR TW 2 KONSOL 2024.pdf
# 63                                                Tambahan modal disetor              22        3.008.083.551                             AGAR TW 2 KONSOL 2024.pdf
# 64                                         Penghasilan komprehensif lain              23          899.672.093                             AGAR TW 2 KONSOL 2024.pdf
# 65                                                                  Laba               1        1.058.036.869                             AGAR TW 2 KONSOL 2024.pdf
# 66                                                                Jumlah                      106.965.792.513                             AGAR TW 2 KONSOL 2024.pdf
# 67                                            Kepentingan non-pengendali              70             (19.757)                             AGAR TW 2 KONSOL 2024.pdf
# 68                                           JUMLAH EKUITAS TOTAL EQUITY                      106.965.772.756                             AGAR TW 2 KONSOL 2024.pdf
# 69                               JUMLAH KEWAJIBAN DAN EKUITAS AND EQUITY                      196.914.899.870                             AGAR TW 2 KONSOL 2024.pdf
# 70                                            PT ASIA SEJAHTERA MINA TBK                                    ,                             AGAR TW 2 KONSOL 2024.pdf
# 71                                         PADA JUNI DAN (TIDAK DIAUDIT)               3                    0                             AGAR TW 2 KONSOL 2024.pdf
# 72                                                  JUNE AND (UNAUDITED)              30                    ,                             AGAR TW 2 KONSOL 2024.pdf
# 73                                                                                     3                    3
# 74                                                              Catatan/              30                 2024                             AGAR TW 2 KONSOL 2024.pdf
# 75                                                                 Notes              30                 2024                             AGAR TW 2 KONSOL 2024.pdf
# 76                                            PENJUALAN BERSIH NET SALES              24      157.707.918.480                             AGAR TW 2 KONSOL 2024.pdf
# 77                                            BEBAN POKOK PENJUALAN COST              25    (142.600.768.775)                             AGAR TW 2 KONSOL 2024.pdf
# 78                                               LABA KOTOR GROSS PROFIT              15       19.170.293.134                             AGAR TW 2 KONSOL 2024.pdf
# 79                                                           Beban usaha              26     (13.508.791.843)                             AGAR TW 2 KONSOL 2024.pdf
# 80                                                  Pendapatan lain-lain              27          246.479.816                             AGAR TW 2 KONSOL 2024.pdf
# 81                                                       Beban lain-lain              28      (3.071.839.411)                             AGAR TW 2 KONSOL 2024.pdf
# 82                           JUMLAH BEBAN USAHA TOTAL OPERATING EXPENSES              16     (17.950.375.057)                             AGAR TW 2 KONSOL 2024.pdf
# 83                                          PAJAK PENGHASILAN INCOME TAX               1        1.219.918.077                             AGAR TW 2 KONSOL 2024.pdf
# 84                                               BEBAN PAJAK PENGHASILAN             29c         (13.127.620)                             AGAR TW 2 KONSOL 2024.pdf
# 85                                    LABA (RUGI) BERSIH NET GAIN (LOSS)               1          895.434.247                             AGAR TW 2 KONSOL 2024.pdf
# 86                                              KOMPREHENSIF GAIN (LOSS)               1          895.434.247                             AGAR TW 2 KONSOL 2024.pdf
# 87                                                 Pemilik entitas induk               1          895.458.414                             AGAR TW 2 KONSOL 2024.pdf
# 88                                            Kepentingan non pengendali              51             (24.167)                             AGAR TW 2 KONSOL 2024.pdf
# 89                                           TAHUN BERJALAN FOR THE YEAR               1          895.434.247                             AGAR TW 2 KONSOL 2024.pdf
# 90                                                 Pemilik entitas induk               1          895.458.414                             AGAR TW 2 KONSOL 2024.pdf
# 91                                            Kepentingan non pengendali              51             (24.167)                             AGAR TW 2 KONSOL 2024.pdf
# 92                       KOMPREHENSIF TAHUN BERJALAN (LOSS) FOR THE YEAR               1          895.434.247                             AGAR TW 2 KONSOL 2024.pdf
# 93                    LABA (LOSS) PER LEMBAR SAHAM GAIN (LOSS) PER SHARE               0              0,72159                             AGAR TW 2 KONSOL 2024.pdf
# 94                                            PT ASIA SEJAHTERA MINA TBK                                    ,                             AGAR TW 2 KONSOL 2024.pdf
# 95                           UNTUK PERIODE ENAM BULAN YANG BERAKHIR JUNI              30                 2024                             AGAR TW 2 KONSOL 2024.pdf
# 96                                  FOR THE SIX MONTHS PERIOD ENDED JUNE              30                    ,                             AGAR TW 2 KONSOL 2024.pdf
# 97                                                                                     4                    4
# 98                                                                 Saldo               1                 2023                             AGAR TW 2 KONSOL 2024.pdf
# 99                              dari penerapan PSAK - - - - - - - - PSAK              24                   24                             AGAR TW 2 KONSOL 2024.pdf
# 100                                   Laba bersih tahun berjalan - - - -              24          895.458.414                             AGAR TW 2 KONSOL 2024.pdf
# 101                                                                Saldo              30                 2023                             AGAR TW 2 KONSOL 2024.pdf
# 102                                                                Saldo               1                 2024                             AGAR TW 2 KONSOL 2024.pdf
# 103                             dari penerapan PSAK - - - - - - - - PSAK              24                   24                             AGAR TW 2 KONSOL 2024.pdf
# 104                                   Rugi bersih tahun berjalan - - - -               1      (1.240.078.338)                             AGAR TW 2 KONSOL 2024.pdf
# 105                                                                Saldo              30                 2024                             AGAR TW 2 KONSOL 2024.pdf
# 106                                           PT ASIA SEJAHTERA MINA TBK                                    ,                             AGAR TW 2 KONSOL 2024.pdf
# 107                                                 JUNI (TIDAK DIAUDIT)              30                 2024                             AGAR TW 2 KONSOL 2024.pdf
# 108                                                     JUNE (UNAUDITED)              30                  202                             AGAR TW 2 KONSOL 2024.pdf
# 109                                                                                    5                    5
# 110                                                                                                      2023
# 111                                        Penerimaan kas dari pelanggan                      267.026.244.390                             AGAR TW 2 KONSOL 2024.pdf
# 112                                                        Cash payments                    (264.460.593.050)                             AGAR TW 2 KONSOL 2024.pdf
# 113                            Pembayaran beban usaha operating expenses              13     (18.576.402.902)                             AGAR TW 2 KONSOL 2024.pdf
# 114                                                    pajak penghasilan               1        (395.143.731)                             AGAR TW 2 KONSOL 2024.pdf
# 115                                     Penerimaan (Pembayaraan) lainnya                          854.393.809                             AGAR TW 2 KONSOL 2024.pdf
# 116                                                    aktivitas operasi               4     (15.551.501.484)                             AGAR TW 2 KONSOL 2024.pdf
# 117                                                 Perolehan aset tetap               1        (252.850.385)                             AGAR TW 2 KONSOL 2024.pdf
# 118                                                     Aset lain-lain -                        (412.046.250)                             AGAR TW 2 KONSOL 2024.pdf
# 119                                                  aktivitas investasi               1        (664.896.635)                             AGAR TW 2 KONSOL 2024.pdf
# 120                                           Pembayaran pinjaman bank -               3      (3.394.118.809)                             AGAR TW 2 KONSOL 2024.pdf
# 121                                            jangka panjang bank loans               1      (1.394.111.760)                             AGAR TW 2 KONSOL 2024.pdf
# 122                                    lembaga keuangan - loans received              11       11.955.168.634                             AGAR TW 2 KONSOL 2024.pdf
# 123                                       aktivitas investasi activities              10      (4.788.230.569)                             AGAR TW 2 KONSOL 2024.pdf
# 124                                           kas dan bank cash and bank               7     (21.004.628.688)                             AGAR TW 2 KONSOL 2024.pdf
# 125                                               awal periode beginning               6       25.911.737.517                             AGAR TW 2 KONSOL 2024.pdf
# 126                                               pada akhir periode end              14        4.907.108.829                             AGAR TW 2 KONSOL 2024.pdf
# 127                                                              tanggal              31                 2024   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 128                         dan untuk periode (tiga) bulan yang berakhir               3                    3   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 129                                                         pada tanggal              31                 2024   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 130                                                                   as              31                  202   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 131                              and for the (three) months period ended               3                    3   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 132                                                March and (Unaudited)              31                 2024   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 133                                                                  are                                    .   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 134                                                 TANGGAL MARET (Tidak              31                 2024   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 135                                                   DESEMBER (Diaudit)              31                 2023   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 136                                  DAN UNTUK PERIODE (TIGA) BULAN YANG               3                    3   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 137                                          BERAKHIR PADA TANGGAL MARET              31                 2024   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 138                                                           DAN (Tidak                                 2023   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 139                                                                   AS              31                 2024   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 140                                                   DECEMBER (Audited)              31                 2023   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 141                              AND FOR THE (Three) MONTHS PERIOD ENDED               3                    3   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 142                                                MARCH AND (Unaudited)              31                 2024   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 143                                                              Laporan               1                    1   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 144                                                              Laporan                  ...................   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 145                                                          Penghasilan               4                    4   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 146                                                              Laporan               6                    6   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 147                                                              Laporan               7                .....   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 148                                                         Catatan atas               8                    8   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 149                                                                  are                                    .   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 150                                                        konsolidasian                                    .   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 151                                                           statements                                    .   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 152                                                                                    1                    1
# 153                                                              Tanggal              31                 2024   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 154                                                   Desember (Diaudit)              31                  202   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 155                                              (Disajikan dalam jutaan                                    ,   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 156                                                                   As              31                 2024   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 157                                                   December (Audited)              31                 2023   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 158                                                           (Expressed                                    ,   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 159                                                              Maret /              31                   31   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 160                                                             Catatan/              31                  31,   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 161                                                                Notes                                 2023   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 162                                                   Kas dan setara kas               4               94.887   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 163                                                 Piutang usaha - neto               5                    5   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 164                                                         Pihak ketiga              17                7.759   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 165                                                       Pihak berelasi               6              335.769   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 166                                         Aset keuangan lancar lainnya              8a                1.912   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 167                                                    Persediaan - neto               7              106.427   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 168                                                        Pajak dibayar              9a               14.488   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 169                                                        Biaya dibayar             10a                7.897   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 170                                                       lancar lainnya             10b               22.752   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 171                                                                                   13                    7
# 172                                                    Aset tetap - neto              11             1.066.00   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 173                                                   Properti investasi              13               32.193   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 174                                                             Goodwill             12a                  729   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 175                                            Tagihan pajak penghasilan              9b                8.848   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 176                                             Aset takberw ujud - neto             12b              230.785   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 177                                                       lainnya assets               3                2.351   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 178                                tidak lancar lainnya financial assets              51                   50   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 179                                                                                    1                    2
# 180                                                                                    1            1.850.004
# 181                                                                  are                                    .   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 182                                                        konsolidasian                                    .   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 183                                                           statements                                    .   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 184                                            PT FKS FOOD SEJAHTERA TBK               2                    2   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 185                                                              Tanggal              31                 2024   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 186                                                   Desember (Diaudit)              31                 2023   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 187                                              (Disajikan dalam jutaan                                    ,   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 188                                                                   As              31                  202   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 189                                                   December (Audited)              31                 2023   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 190                                                           (Expressed                                    ,   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 191                                                              Maret /              31                   31   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 192                                                             Catatan/              31                  31,   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 193                                                                Notes                                 2023   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 194                                                          Utang usaha              14                   14   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 195                                                         Pihak ketiga                              151.291   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 196                                                       Pihak berelasi               6               25.070   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 197                                 Beban akrual dan provisi provision s              15              166.953   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 198                                                          Utang pajak              9c               36.034   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 199                                            jangka pendek liabilities              42               32.500   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 200                                             Utang bank jangka pendek             17a               93.573   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 201                                                           Utang bank             17b                   17   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 202                                                      Liabilitas sewa              16               21.350   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 203                                                       pendek lainnya              8b               71.809   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 204                                                  non-usaha non-trade               6               82.898   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 205                                                   Liabilitas kontrak               3                3.987   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 206                                                               Jangka                              659.907   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 207                                            Utang bank jangka panjang                                    ,   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 208                                                    setelah dikurangi                                    ,   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 209                                                        bagian lancar             17b               69.048   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 210                                                      Liabilitas sewa                                    ,   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 211                                                    setelah dikurangi                                    ,   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 212                                                    bagian lancar net              16               35.343   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 213                                    Liabilitas pajak tangguhan - neto              9e               51.242   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 214                           Liabilitas imbalan pasca kerja liabilities              18               65.897   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 215                                                               Jangka                              221.899   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 216                                                                                                   881.806
# 217                                                                  are                                    .   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 218                                                        konsolidasian                                    .   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 219                                                           statements                                    .   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 220                                            PT FKS FOOD SEJAHTERA TBK               3                    3   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 221                                                              Tanggal              31                 2024   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 222                                                   Desember (Diaudit)              31                 2023   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 223                                              (Disajikan dalam jutaan                                    ,   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 224                                                                   As              31                  202   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 225                                                   December (Audited)              31                 2023   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 226                                                           (Expressed                                    ,   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 227                                                              Maret /              31                   31   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 228                                                             Catatan/              31                  31,   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 229                                                                Notes                                 2023   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 230                                                        Saham seri A:                                  500   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 231                                                        Saham seri B:                                  200   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 232                                                        Saham seri A:                          135,000,000   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 233                                                         saham shares              18       18,662,500,000   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 234                                                        Saham seri A:                          135,000,000   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 235                                                        Saham seri B:               9        9.176.800.000   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 236                                                       saham shares :              19            1.902.860   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 237                                        Tambahan modal disetor - neto              20            1.515.597   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 238                                        Penghasilan komprehensif lain              21              502.316   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 239                                                            Defisit )               2           (2.960.347   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 240                                                                                                   969.551
# 241                                                          Kepentingan               1                   0)   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 242                                                                                                   968.198
# 243                                                                                    1            1.850.004
# 244                                                                  are                                    .   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 245                                                        konsolidasian                                    .   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 246                                                           statements                                    .   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 247                                                                                    4                    4
# 248                                    Untuk periode (tiga) bulanan yang               3                    3   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 249                                                              tanggal              30                 2024   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 250                                              (Disajikan dalam jutaan                                    ,   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 251                                  For the (three) months period ended               3                    3   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 252                                                          March and (              31                 2024   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 253                                                           (Expressed                                    ,   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 254                                                       bulan / months               3                    3   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 255                                                                Notes                                 2023   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 256                                                       Penjualan neto              22                   22   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 257                                            Beban pokok penjualan ) )              23                   23   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 258                                                           Laba bruto                              134.136   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 259                                     Beban penjualan dan distribusi )              88                   24   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 260                                      Beban umum dan administrasi ) )              55                   25   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 261                                                  Penghasilan lainnya               1                   26   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 262                                                      Beban lainnya )               4                   27   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 263                                                           Laba usaha              27               13.513   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 264                                                 Penghasilan keuangan              28                   28   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 265                                                   Beban keuangan ) )               6                   29   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 266                                                    pajak penghasilan              21                    4   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 267                                              Beban pajak penghasilan              9d                    9   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 268                                                  Laba tahun berjalan              10                2.101   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 269                                   program imbalan pasti benefit plan               3                   18   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 270                   kembali program imbalan pasti defined benefit plan               9                    9   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 271                                                 Revaluasi aset tetap               2                    9   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 272                                     lain tahun berjalan for the year               4                2.158   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 273                                   tahun berjalan income for the year              15                4.259   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 274                                                Pemilik entitas induk              10                2.099   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 275                                            Kepentingan nonpengendali               4                    2   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 276                                                                                   10                2.101
# 277                                                   MARET DAN DESEMBER              31                 2024                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 278                                     YANG BERAKHIR PADA TANGGAL MARET              31                 2024                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 279                                                 MARET (TIDAK DIUDIT)              31                2023)                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 280                                                   MARCH AND DECEMBER              31                 2024                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 281                                                   PERIOD ENDED MARCH              31                 2024                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 282                                                    MARCH (UNAUDITED)              31                  202                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 283                                                                  are                                    .                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 284                                                   MARET DAN DESEMBER              31                 2024                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 285                                     PADA TANGGAL MARET (DENGAN ANGKA              31                 2024                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 286                                    PADA TANGGAL MARET (TIDAK DIUDIT)              31                2023)                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 287                                                   MARCH AND DECEMBER              31                  202                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 288                                      MARCH (WITH COMPARATIVE FIGURES              31                  202                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# ...
# 442                                       DESEMBER MARCH (UNAUDITED) AND              31                 2023  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 443                                                             DECEMBER              31                 2023  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 444                                                     (Disajikan dalam                                    ,  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 445                                                   secara keseluruhan                                    .  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 446                                                          Halaman - -               1                   31  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 447                                                                March                                 2024  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 448                                                                Notes              31                   31  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 449                                                             December                                 2023  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 450                                                   Kas dan setara kas          2a, 2b                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 451                                                Pihak ketiga – bersih          2a, 2d                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 452                                                         Pihak ketiga       2a, 2d, 6                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 453                                                      Portofolio efek       2a, 2j, 8                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 454                                                           Persediaan       2a, 2g, 7                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 455                                                        dan uang muka       2a, 2f, 9                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 456                                                 LANCAR TOTAL CURRENT              74       26.783.474.495  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 457                                                               ASSETS              00                   00  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 458                                                       Pihak berelasi          2a, 2d                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 459                                                         Pihak ketiga              16           28.164.545  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 460                                                      Aset lain -lain          2a, 10                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 461                                                  Aset tetap – bersih          2a, 2h                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 462                                                 Aset pajak tangguhan           2a, 2                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 463                                      TIDAK LANCAR TOTAL NON -CURRENT              82       80.146.601.751  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 464                                             JUMLAH ASET TOTAL ASSETS                      106.930.076.246  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 465                                                                   in                                    .  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 466                                            MARET (TIDAK DIAUDIT) DAN              31                 2024  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 467                                       DESEMBER MARCH (UNAUDITED) AND              31                 2023  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 468                                                             DECEMBER              31                 2023  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 469                                                     (Disajikan dalam                                    ,  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 470                                                   secara keseluruhan                                    .  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 471                                                          Halaman - -               2                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 472                                                               Maret/              31                   31  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 473                                                                March                                 2024  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 474                                                                Notes              31                   31  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 475                                                                                                      2023
# 476                                                         Pihak ketiga       2a, 2k, 1                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 477                                                  Uang muka pelanggan      2a, 2l, 13                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 478                                                              dibayar      2a, 2l, 14                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 479                                                           Utang bank           2a, 1                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 480                                                          Utang pajak           2a, 2                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 481                                          JANGKA PENDEK TOTAL CURRENT              23       47.891.113.389  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 482                                             Liabilitas imbalan kerja       2a, 2m, 1                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 483                                    JANGKA PANJANG TOTAL NON -CURRENT               2        2.359.093.653  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 484                                  JUMLAH LIABILITAS TOTAL LIABILITIES              26       50.250.207.042  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 485                                                                 seri              20                   20  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 486                                                            per saham               6       55.378.870.020  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 487                                              Share capital – nominal              18       41.502.310.020  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 488                                                               series              20                   20  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 489                                                            per share               6                    6  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 490                                               Tambahan modal disetor              63                   19  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 491                                                           Saldo laba               9                    0  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 492                                                        penggunaannya              20                   20  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 493                                                        penggunaannya               2        4.756.771.798  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 494                                               komprehensif lainnya )                         (212.237.951  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 495                                                         JUMLAH EKUIT              56       56.679.869.204  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 496                                                            DAN EKUIT                      106.930.076.246  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 497                                                                   in                                    .  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 498                      MARET DAN (TIDAK DIAUDIT) MARCH AND (UNAUDITED)              31                 2024  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 499                                                     (Disajikan dalam                                    ,  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 500                                                   secara keseluruhan                                    .  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 501                                                          Halaman - -               3                    3  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 502                                                               Maret/              31                   31  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 503                                                             Catatan/                                 2024  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 504                                                               Maret/              31                   31  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 505                                                                                                      2023
# 506                                                            PENJUALAN  2a, 2e, 2l, 21                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 507                                                            PENJUALAN           2a, 2                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 508                                              LABA KOTOR GROSS PROFIT               6        3.636.580.875  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 509                                                             dan umum           2a, 2                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 510                                                       selisih kurs )          2a, 2l                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 511                                                  operasional lainnya  2a, 2e, 2l, 24                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 512                                                          terealisasi              16                    9  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 513                                                                    a           2a, 8                    ,  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 514                                               Unrealized gain (loss)              16                    9  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 515                                                  operasional lainnya          2a, 2l                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 516                                             LABA OPERASI INCOME FROM               3        2.446.724.043  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 517                                                  Pendapatan keuangan           2a, 2                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 518                                                     Beban keuangan )           2a, 2                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 519                                            PENGHASILAN INCOME BEFORE               3        1.989.123.739  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 520                                                     penghasilan kini  2a, 2l, 2n,16B                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 521                                                            tangguhan          2a, 2n                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 522                                                                    c             16c           32.052.869  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 523                                      TAHUN BERJALAN CURRENT YEAR NET               2        1.069.405.568  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 524                                                                   in                                    .  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 525                      MARET DAN (TIDAK DIAUDIT) MARCH AND (UNAUDITED)              31                 2024  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 526                                                     (Disajikan dalam                                    ,  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 527                                                   secara keseluruhan                                    .  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 528                                                          Halaman - -               4                    4  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 529                                                               Maret/              31                   31  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 530                                                                March                                 2024  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 531                                                               Maret/              31                   31  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 532                                                                March                                 2023  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 533                                      TAHUN BERJALAN CURRENT YEAR NET               2        1.069.405.568  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 534                                                                pasti       2a, 2m, 1                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 535                                                                pasti       2a, 2n, 1                    2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 536                                                  LAIN – BERSIH OTHER              27        (101.482.728)  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 537                                         TAHUN BERJALAN TOTAL CURRENT               2          967.922.840  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 538                                                       LABA PER SAHAM          2r, 27                    ,  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf

# %%
def extract_text_from_pdf(pdf_path, start_page=1, end_page=None):
    """
    Extract text content from a PDF file, limited to specific page range.
    """
    try:
        reader = PdfReader(pdf_path)
        text_content = ""
        total_pages = len(reader.pages)

        # Adjust end_page if it's not provided or exceeds total pages
        if end_page is None or end_page > total_pages:
            end_page = total_pages

        # Extract text from the specified page range
        for page_num in range(start_page - 1, end_page):
            page = reader.pages[page_num]
            text_content += page.extract_text() + "\n"
        return text_content
    except Exception as e:
        print(f"Error reading PDF {pdf_path}: {str(e)}")
        return None


def extract_table_data(text_content, filename):
    """
    Extract table data from text content with notes and values.
    Handles different table formats where notes and values might be in different positions.
    """
    # Split content into lines
    lines = text_content.split('\n')

    # Initialize lists to store extracted data
    items = []
    values = []
    notes = []
    file_sources = []  # To track which file each row came from

    # Regular expressions for matching
    number_pattern = r'\(?[\d,.]+\)?'  # Matches numbers with 6 or more digits

    # First notes pattern: Matches patterns like 2f, 2v, or 2v,2g
    notes_pattern_1 = r'\d+[a-zA-Z](?:,\s?[a-zA-Z\d]+)*'  # Matches patterns like 2v, 2g, 3f, or 2v,2g

    # Second notes pattern: Matches just numbers (like 22)
    notes_pattern_2 = r'\b\d{1,2}(?:,\s?\d{1,2})*\b'

    for line in lines:
        # Clean the line
        line = line.strip()

        # Try to identify components
        number_match = re.search(number_pattern, line)
        notes_match_1 = re.search(notes_pattern_1, line)
        notes_match_2 = re.search(notes_pattern_2, line)

        if number_match:
            # Extract the item name by removing numbers and notes
            item = re.sub(number_pattern, '', line)  # Remove numbers from item
            item = re.sub(notes_pattern_1, '', item)  # Remove notes from item
            item = re.sub(notes_pattern_2, '', item)  # Remove additional notes
            item = re.sub(r'\s+', ' ', item).strip()  # Replace multiple spaces with a single space

            # Remove empty parentheses and remaining text after them
            item = re.sub(r'\(\s*\).*', '', item).strip()

            # Remove single or double letters and all remaining text after them
            item = re.sub(r'\s[a-zA-Z]{1,2}\s.*', '', item).strip()

            # # Remove remaining words if they start with an uppercase letter
            # item = re.sub(r'\s[A-Z][a-zA-Z]*.*', '', item).strip()

            # Remove remaining words if they start with an uppercase letter, but not all caps
            item = re.sub(r'\s([A-Z][a-z][a-zA-Z]*)\b.*', '', item).strip()

            numbers = re.findall(number_pattern, line)
            if len(numbers) > 1:
                # General case: pick the second number, or use any logic to decide which number to take
                value = numbers[1]  # Take the second number (can be adjusted)
            elif len(numbers) == 1:
                value = numbers[0]
            else:
                # If no numbers found, return an empty string
                value = " "

            # Extract value
            # value = number_match.group()
            
            # Use the first notes pattern if it matches (allows comma-separated notes)
            if notes_match_1:
                note = notes_match_1.group()
            # Only use the second notes pattern if the first one didn't match
            elif notes_match_2 and not notes_match_1:
                note = notes_match_2.group()
            else:
                note = ""  # Default case if no notes are found

            # Modify values: remove commas, periods, and handle parentheses for negative values
            if value.startswith('(') and value.endswith(')'):
                # Remove parentheses, then make it negative
                value = '-' + value[1:-1].replace('.', '').replace(',', '')
            else:
                # Just remove commas and periods
                value = value.replace('.', '').replace(',', '')

            
            # Directly append to lists without any additional condition
            values.append(value)
            notes.append(note)

            # Only include if we have all components and it's not a total
            if item and not item.lower().startswith('total'):
                items.append(item)
                file_sources.append(filename)  # Add filename to track source

            # Ensure lists remain the same length by filling any missing values
            while len(items) < len(values):
                items.append("")
            while len(notes) < len(values):
                notes.append("")
            while len(file_sources) < len(values):
                file_sources.append("")

    # Create DataFrame
    df = pd.DataFrame({
        'Item': items,
        'Notes': notes,
        'Value': values,
        'Source_File': file_sources
    })
    
    return df


# import re
# import pandas as pd

# def extract_table_data(text_content, filename):
#     """
#     Extract table data from text content with notes and values.
#     Handles different table formats where notes and values might be in different positions.
#     """
#     # Split content into lines
#     lines = text_content.split('\n')

#     # Initialize lists to store extracted data
#     items = []
#     values = []
#     notes = []
#     file_sources = []  # To track which file each row came from

#     # Regular expressions for matching
#     number_pattern = r'[\d,.]+'  # Matches numbers with commas and periods

#     # First notes pattern: Matches patterns like 2f, 2v, or 2v,2g
#     notes_pattern_1 = r'\d+[a-zA-Z](?:,\s?[a-zA-Z\d]+)*'  # Matches patterns like 2v, 2g, 3f, or 2v,2g

#     # Second notes pattern: Matches just numbers (like 22)
#     notes_pattern_2 = r'\b\d{1,2}(?:,\s?\d{1,2})*\b'

#     for line in lines:
#         # Clean the line
#         line = line.strip()

#         # Try to identify components
#         notes_match_1 = re.search(notes_pattern_1, line)
#         notes_match_2 = re.search(notes_pattern_2, line)

#         # Extract numbers from the line
#         numbers = re.findall(number_pattern, line)
        
#         # Default value for note and value
#         note = ""
#         value = ""

#         # Case 1: If notes pattern 1 matches (like 29d, 2f)
#         if notes_match_1:
#             note = notes_match_1.group()  # Capture the notes (e.g., '29d')
#             # Find numbers after the note
#             notes_end_pos = line.find(note) + len(note)
#             line_after_notes = line[notes_end_pos:].strip()
#             numbers_after_notes = re.findall(number_pattern, line_after_notes)
#             value = numbers_after_notes[0] if numbers_after_notes else numbers[0]  # Value after notes, or first number

#         # Case 2: If notes pattern 2 matches (like 22, 12)
#         elif notes_match_2:
#             note = notes_match_2.group()  # Capture the notes (e.g., '22')
#             # Take the first number as the value
#             value = numbers[0] if numbers else ""

#         # Case 3: If no notes pattern matches, take the first number as the value
#         elif numbers:
#             value = numbers[0]

#         # Clean the item name by removing numbers and notes
#         item = re.sub(number_pattern, '', line)  # Remove all numbers from item
#         item = re.sub(f"{note}$", '', item).strip()  # Remove notes from item
#         item = re.sub(r'\s+', ' ', item).strip()  # Replace multiple spaces with a single space

#         # Clean up further
#         item = re.sub(r'\(\s*\).*', '', item).strip()  # Remove empty parentheses and text after them
#         item = re.sub(r'\s[a-zA-Z]{1,2}\s.*', '', item).strip()  # Remove single/double letters and text after them
#         item = re.sub(r'\s([A-Z][a-z][a-zA-Z]*)\b.*', '', item).strip()  # Remove words starting with uppercase letters

#         # Append the extracted values
#         values.append(value)
#         notes.append(note)

#         # Only include if we have all components and it's not a total
#         if item and not item.lower().startswith('total'):
#             items.append(item)
#             file_sources.append(filename)  # Add filename to track source

#         # Ensure lists remain the same length by filling any missing values
#         while len(items) < len(values):
#             items.append("")
#         while len(notes) < len(values):
#             notes.append("")
#         while len(file_sources) < len(values):
#             file_sources.append("")

#     # Create DataFrame
#     df = pd.DataFrame({
#         'Item': items,
#         'Notes': notes,
#         'Value': values,
#         'Source_File': file_sources
#     })
    
#     return df




def process_folder(folder_path, start_page=1, end_page=8):
    """
    Process all PDF files in a folder and combine results, limited to specific page range.
    """
    # List to store all DataFrames
    all_dfs = []

    # Get all PDF files in the folder
    pdf_files = [f for f in os.listdir(folder_path) if f.lower().endswith('.pdf')]

    if not pdf_files:
        print(f"No PDF files found in {folder_path}")
        return None

    # Process each PDF file
    for pdf_file in pdf_files:
        print(f"Processing {pdf_file}...")
        pdf_path = os.path.join(folder_path, pdf_file)

        # Extract text from PDF
        text_content = extract_text_from_pdf(pdf_path, start_page, end_page)

        if text_content:
            # Process the content
            df = extract_table_data(text_content, pdf_file)
            if not df.empty:
                all_dfs.append(df)
            else:
                print(f"No relevant data found in {pdf_file}")

    if all_dfs:
        # Combine all DataFrames
        combined_df = pd.concat(all_dfs, ignore_index=True)

        # Clean up the DataFrame
        combined_df['Item'] = combined_df['Item'].str.strip()
        combined_df['Notes'] = combined_df['Notes'].str.strip()
        # combined_df['Value'] = combined_df['Value'].str.strip()

        return combined_df
    else:
        print("No data was extracted from any PDF files")
        return None


def main(folder_path, start_page=1, end_page=8):
    """
    Main function to process folder and save results.
    """
    # Process the folder with specific page range
    df = process_folder(folder_path, start_page, end_page)

    if df is not None:
        # Display summary
        print(f"\nTotal rows extracted: {len(df)}")
        print(f"Files processed: {df['Source_File'].nunique()}")

        # Display sample of results
        print("\nSample of extracted data:")
        print(df.to_string())

    return df

# Example usage
if __name__ == "__main__":
    # Replace with your folder path
    folder_path = "C:/TI-Dwika/Semester 7/Pangkalan Data/file_pdf"
    start_page = 1
    end_page = 8
    df_data = main(folder_path, start_page, end_page)
# Out:
# Processing AGAR TW 2 KONSOL 2024.pdf...
# Processing FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf...
# Processing Lapkeu ABBA 31 Mar 2024 (1).pdf...
# Processing LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf...
#
# Total rows extracted: 539
# Files processed: 5
#
# Sample of extracted data:
#                                                                     Item           Notes          Value                                           Source_File
# 0                                                 PT ASIA SEJAHTERA MINA                                                            AGAR TW 2 KONSOL 2024.pdf
# 1                                                                 JUNI /              30           2024                             AGAR TW 2 KONSOL 2024.pdf
# 2                                                                   JUNE              30            202                             AGAR TW 2 KONSOL 2024.pdf
# 3                                             PT ASIA SEJAHTERA MINA TBK                                                            AGAR TW 2 KONSOL 2024.pdf
# 4                                                             DAFTAR ISI                                                            AGAR TW 2 KONSOL 2024.pdf
# 5                                                               Juni dan              30           2024                             AGAR TW 2 KONSOL 2024.pdf
# 6                                                               Juni dan              30           2024                             AGAR TW 2 KONSOL 2024.pdf
# 7                                             the six month period ended              30            202                             AGAR TW 2 KONSOL 2024.pdf
# 8                                                                    and               3              3                             AGAR TW 2 KONSOL 2024.pdf
# 9                                                                                      1              1
# 10                                                           Kompehensif               3              3                             AGAR TW 2 KONSOL 2024.pdf
# 11                                                               Laporan               4              4                             AGAR TW 2 KONSOL 2024.pdf
# 12                                                               Laporan               5              5                             AGAR TW 2 KONSOL 2024.pdf
# 13                                                          Catatan atas               6              6                             AGAR TW 2 KONSOL 2024.pdf
# 14                                            PT ASIA SEJAHTERA MINA TBK                                                            AGAR TW 2 KONSOL 2024.pdf
# 15                                                  JUNI (TIDAK DIAUDIT)              30           2024                             AGAR TW 2 KONSOL 2024.pdf
# 16                                                      JUNE (UNAUDITED)              30            202                             AGAR TW 2 KONSOL 2024.pdf
# 17                                                                                     1              1
# 18                                                              Catatan/              30           2024                             AGAR TW 2 KONSOL 2024.pdf
# 19                                                                 Notes              30           2024                             AGAR TW 2 KONSOL 2024.pdf
# 20                                                    Kas dan setara kas               4    14047355680                             AGAR TW 2 KONSOL 2024.pdf
# 21                                                              Kas yang               5     1900000000                             AGAR TW 2 KONSOL 2024.pdf
# 22                                            pihak ketiga third parties               6    36522725228                             AGAR TW 2 KONSOL 2024.pdf
# 23                                                     Piutang lain-lain               7              7                             AGAR TW 2 KONSOL 2024.pdf
# 24                                                          Pihak ketiga               8        2500000                             AGAR TW 2 KONSOL 2024.pdf
# 25                                                            Persediaan               8    78031491296                             AGAR TW 2 KONSOL 2024.pdf
# 26                                                  Pajak dibayar dimuka             29a     1197505340                             AGAR TW 2 KONSOL 2024.pdf
# 27                                                   Uang muka pembelian               9    11239481729                             AGAR TW 2 KONSOL 2024.pdf
# 28                                                         Biaya dibayar              10       80995607                             AGAR TW 2 KONSOL 2024.pdf
# 29                                                                Jumlah                   143541791622                             AGAR TW 2 KONSOL 2024.pdf
# 30              akumulasi penyusutan sebesar accumulated depreciation of                                                            AGAR TW 2 KONSOL 2024.pdf
# 31                                                               Rp pada              21    21102003830                             AGAR TW 2 KONSOL 2024.pdf
# 32                                                              Juni dan              30           2024                             AGAR TW 2 KONSOL 2024.pdf
# 33                                                               Rp pada              19    19956724738                             AGAR TW 2 KONSOL 2024.pdf
# 34                                                              Desember              31           2023                             AGAR TW 2 KONSOL 2024.pdf
# 35                                                        Aset lain-lain              12     2189288648                             AGAR TW 2 KONSOL 2024.pdf
# 36                                                  Aset pajak tangguhan             29d     1071584465                             AGAR TW 2 KONSOL 2024.pdf
# 37                                                              Goodwill              13     5321917155                             AGAR TW 2 KONSOL 2024.pdf
# 38                                                                Jumlah              54    53373108248                             AGAR TW 2 KONSOL 2024.pdf
# 39                                              JUMLAH ASET TOTAL ASSETS                   196914899870                             AGAR TW 2 KONSOL 2024.pdf
# 40                                            PT ASIA SEJAHTERA MINA TBK                                                            AGAR TW 2 KONSOL 2024.pdf
# 41                                       JUNI (TIDAK DIAUDIT) - LANJUTAN              30           2024                             AGAR TW 2 KONSOL 2024.pdf
# 42                                          JUNE (UNAUDITED) - CONTINUED              30                                            AGAR TW 2 KONSOL 2024.pdf
# 43                                                                                     2              2
# 44                                                              Catatan/              30           2024                             AGAR TW 2 KONSOL 2024.pdf
# 45                                                                 Notes              30           2024                             AGAR TW 2 KONSOL 2024.pdf
# 46                                                           Utang usaha              14             14                             AGAR TW 2 KONSOL 2024.pdf
# 47                                                          Pihak ketiga              13    13638407079                             AGAR TW 2 KONSOL 2024.pdf
# 48                                                       Utang lain-lain              15      149264284                             AGAR TW 2 KONSOL 2024.pdf
# 49                                                          Beban akrual              16       86238167                             AGAR TW 2 KONSOL 2024.pdf
# 50                                                          Uang titipan              17     1922352000                             AGAR TW 2 KONSOL 2024.pdf
# 51                                                           Utang pajak             29b      149071620                             AGAR TW 2 KONSOL 2024.pdf
# 52                                                            Utang bank              18     6095439944                             AGAR TW 2 KONSOL 2024.pdf
# 53                      yang jatuh tempo dalam satu tahun lease payables              19    62941920635                             AGAR TW 2 KONSOL 2024.pdf
# 54                                                                Jumlah              84    81650705594                             AGAR TW 2 KONSOL 2024.pdf
# 55                             tempo dalam satu tahun current maturities              19     6041150918                             AGAR TW 2 KONSOL 2024.pdf
# 56                                              Liabilitas imbalan kerja              20      863158842                             AGAR TW 2 KONSOL 2024.pdf
# 57                                                                Jumlah               6     8298421520                             AGAR TW 2 KONSOL 2024.pdf
# 58                                                                Jumlah              91    89949127114                             AGAR TW 2 KONSOL 2024.pdf
# 59                                                   Rp per lembar saham                            100                             AGAR TW 2 KONSOL 2024.pdf
# 60                                                    Modal dasar lembar               3     3000000000                             AGAR TW 2 KONSOL 2024.pdf
# 61                                                  penuh - saham shares               1             21                             AGAR TW 2 KONSOL 2024.pdf
# 62                                         pengampunan pajak tax amnesty               2     2000000000                             AGAR TW 2 KONSOL 2024.pdf
# 63                                                Tambahan modal disetor              22     3008083551                             AGAR TW 2 KONSOL 2024.pdf
# 64                                         Penghasilan komprehensif lain              23      899672093                             AGAR TW 2 KONSOL 2024.pdf
# 65                                                                  Laba               1     1058036869                             AGAR TW 2 KONSOL 2024.pdf
# 66                                                                Jumlah                   106965792513                             AGAR TW 2 KONSOL 2024.pdf
# 67                                            Kepentingan non-pengendali              70         -19757                             AGAR TW 2 KONSOL 2024.pdf
# 68                                           JUMLAH EKUITAS TOTAL EQUITY                   106965772756                             AGAR TW 2 KONSOL 2024.pdf
# 69                               JUMLAH KEWAJIBAN DAN EKUITAS AND EQUITY                   196914899870                             AGAR TW 2 KONSOL 2024.pdf
# 70                                            PT ASIA SEJAHTERA MINA TBK                                                            AGAR TW 2 KONSOL 2024.pdf
# 71                                         PADA JUNI DAN (TIDAK DIAUDIT)               3              0                             AGAR TW 2 KONSOL 2024.pdf
# 72                                                  JUNE AND (UNAUDITED)              30                                            AGAR TW 2 KONSOL 2024.pdf
# 73                                                                                     3              3
# 74                                                              Catatan/              30           2024                             AGAR TW 2 KONSOL 2024.pdf
# 75                                                                 Notes              30           2024                             AGAR TW 2 KONSOL 2024.pdf
# 76                                            PENJUALAN BERSIH NET SALES              24   157707918480                             AGAR TW 2 KONSOL 2024.pdf
# 77                                            BEBAN POKOK PENJUALAN COST              25  -142600768775                             AGAR TW 2 KONSOL 2024.pdf
# 78                                               LABA KOTOR GROSS PROFIT              15    19170293134                             AGAR TW 2 KONSOL 2024.pdf
# 79                                                           Beban usaha              26   -13508791843                             AGAR TW 2 KONSOL 2024.pdf
# 80                                                  Pendapatan lain-lain              27      246479816                             AGAR TW 2 KONSOL 2024.pdf
# 81                                                       Beban lain-lain              28    -3071839411                             AGAR TW 2 KONSOL 2024.pdf
# 82                           JUMLAH BEBAN USAHA TOTAL OPERATING EXPENSES              16   -17950375057                             AGAR TW 2 KONSOL 2024.pdf
# 83                                          PAJAK PENGHASILAN INCOME TAX               1     1219918077                             AGAR TW 2 KONSOL 2024.pdf
# 84                                               BEBAN PAJAK PENGHASILAN             29c      -13127620                             AGAR TW 2 KONSOL 2024.pdf
# 85                                    LABA (RUGI) BERSIH NET GAIN (LOSS)               1      895434247                             AGAR TW 2 KONSOL 2024.pdf
# 86                                              KOMPREHENSIF GAIN (LOSS)               1      895434247                             AGAR TW 2 KONSOL 2024.pdf
# 87                                                 Pemilik entitas induk               1      895458414                             AGAR TW 2 KONSOL 2024.pdf
# 88                                            Kepentingan non pengendali              51         -24167                             AGAR TW 2 KONSOL 2024.pdf
# 89                                           TAHUN BERJALAN FOR THE YEAR               1      895434247                             AGAR TW 2 KONSOL 2024.pdf
# 90                                                 Pemilik entitas induk               1      895458414                             AGAR TW 2 KONSOL 2024.pdf
# 91                                            Kepentingan non pengendali              51         -24167                             AGAR TW 2 KONSOL 2024.pdf
# 92                       KOMPREHENSIF TAHUN BERJALAN (LOSS) FOR THE YEAR               1      895434247                             AGAR TW 2 KONSOL 2024.pdf
# 93                    LABA (LOSS) PER LEMBAR SAHAM GAIN (LOSS) PER SHARE               0         072159                             AGAR TW 2 KONSOL 2024.pdf
# 94                                            PT ASIA SEJAHTERA MINA TBK                                                            AGAR TW 2 KONSOL 2024.pdf
# 95                           UNTUK PERIODE ENAM BULAN YANG BERAKHIR JUNI              30           2024                             AGAR TW 2 KONSOL 2024.pdf
# 96                                  FOR THE SIX MONTHS PERIOD ENDED JUNE              30                                            AGAR TW 2 KONSOL 2024.pdf
# 97                                                                                     4              4
# 98                                                                 Saldo               1           2023                             AGAR TW 2 KONSOL 2024.pdf
# 99                              dari penerapan PSAK - - - - - - - - PSAK              24             24                             AGAR TW 2 KONSOL 2024.pdf
# 100                                   Laba bersih tahun berjalan - - - -              24      895458414                             AGAR TW 2 KONSOL 2024.pdf
# 101                                                                Saldo              30           2023                             AGAR TW 2 KONSOL 2024.pdf
# 102                                                                Saldo               1           2024                             AGAR TW 2 KONSOL 2024.pdf
# 103                             dari penerapan PSAK - - - - - - - - PSAK              24             24                             AGAR TW 2 KONSOL 2024.pdf
# 104                                   Rugi bersih tahun berjalan - - - -               1    -1240078338                             AGAR TW 2 KONSOL 2024.pdf
# 105                                                                Saldo              30           2024                             AGAR TW 2 KONSOL 2024.pdf
# 106                                           PT ASIA SEJAHTERA MINA TBK                                                            AGAR TW 2 KONSOL 2024.pdf
# 107                                                 JUNI (TIDAK DIAUDIT)              30           2024                             AGAR TW 2 KONSOL 2024.pdf
# 108                                                     JUNE (UNAUDITED)              30            202                             AGAR TW 2 KONSOL 2024.pdf
# 109                                                                                    5              5
# 110                                                                                                2023
# 111                                        Penerimaan kas dari pelanggan                   267026244390                             AGAR TW 2 KONSOL 2024.pdf
# 112                                                        Cash payments                  -264460593050                             AGAR TW 2 KONSOL 2024.pdf
# 113                            Pembayaran beban usaha operating expenses              13   -18576402902                             AGAR TW 2 KONSOL 2024.pdf
# 114                                                    pajak penghasilan               1     -395143731                             AGAR TW 2 KONSOL 2024.pdf
# 115                                     Penerimaan (Pembayaraan) lainnya                      854393809                             AGAR TW 2 KONSOL 2024.pdf
# 116                                                    aktivitas operasi               4   -15551501484                             AGAR TW 2 KONSOL 2024.pdf
# 117                                                 Perolehan aset tetap               1     -252850385                             AGAR TW 2 KONSOL 2024.pdf
# 118                                                     Aset lain-lain -                     -412046250                             AGAR TW 2 KONSOL 2024.pdf
# 119                                                  aktivitas investasi               1     -664896635                             AGAR TW 2 KONSOL 2024.pdf
# 120                                           Pembayaran pinjaman bank -               3    -3394118809                             AGAR TW 2 KONSOL 2024.pdf
# 121                                            jangka panjang bank loans               1    -1394111760                             AGAR TW 2 KONSOL 2024.pdf
# 122                                    lembaga keuangan - loans received              11    11955168634                             AGAR TW 2 KONSOL 2024.pdf
# 123                                       aktivitas investasi activities              10    -4788230569                             AGAR TW 2 KONSOL 2024.pdf
# 124                                           kas dan bank cash and bank               7   -21004628688                             AGAR TW 2 KONSOL 2024.pdf
# 125                                               awal periode beginning               6    25911737517                             AGAR TW 2 KONSOL 2024.pdf
# 126                                               pada akhir periode end              14     4907108829                             AGAR TW 2 KONSOL 2024.pdf
# 127                                                              tanggal              31           2024   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 128                         dan untuk periode (tiga) bulan yang berakhir               3              3   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 129                                                         pada tanggal              31           2024   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 130                                                                   as              31            202   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 131                              and for the (three) months period ended               3              3   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 132                                                March and (Unaudited)              31           2024   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 133                                                                  are                                  FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 134                                                 TANGGAL MARET (Tidak              31           2024   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 135                                                   DESEMBER (Diaudit)              31           2023   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 136                                  DAN UNTUK PERIODE (TIGA) BULAN YANG               3              3   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 137                                          BERAKHIR PADA TANGGAL MARET              31           2024   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 138                                                           DAN (Tidak                           2023   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 139                                                                   AS              31           2024   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 140                                                   DECEMBER (Audited)              31           2023   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 141                              AND FOR THE (Three) MONTHS PERIOD ENDED               3              3   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 142                                                MARCH AND (Unaudited)              31           2024   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 143                                                              Laporan               1              1   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 144                                                              Laporan                                  FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 145                                                          Penghasilan               4              4   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 146                                                              Laporan               6              6   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 147                                                              Laporan               7                  FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 148                                                         Catatan atas               8              8   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 149                                                                  are                                  FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 150                                                        konsolidasian                                  FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 151                                                           statements                                  FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 152                                                                                    1              1
# 153                                                              Tanggal              31           2024   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 154                                                   Desember (Diaudit)              31            202   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 155                                              (Disajikan dalam jutaan                                  FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 156                                                                   As              31           2024   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 157                                                   December (Audited)              31           2023   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 158                                                           (Expressed                                  FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 159                                                              Maret /              31             31   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 160                                                             Catatan/              31             31   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 161                                                                Notes                           2023   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 162                                                   Kas dan setara kas               4          94887   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 163                                                 Piutang usaha - neto               5              5   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 164                                                         Pihak ketiga              17           7759   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 165                                                       Pihak berelasi               6         335769   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 166                                         Aset keuangan lancar lainnya              8a           1912   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 167                                                    Persediaan - neto               7         106427   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 168                                                        Pajak dibayar              9a          14488   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 169                                                        Biaya dibayar             10a           7897   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 170                                                       lancar lainnya             10b          22752   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 171                                                                                   13              7
# 172                                                    Aset tetap - neto              11         106600   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 173                                                   Properti investasi              13          32193   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 174                                                             Goodwill             12a            729   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 175                                            Tagihan pajak penghasilan              9b           8848   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 176                                             Aset takberw ujud - neto             12b         230785   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 177                                                       lainnya assets               3           2351   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 178                                tidak lancar lainnya financial assets              51             50   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 179                                                                                    1              2
# 180                                                                                    1        1850004
# 181                                                                  are                                  FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 182                                                        konsolidasian                                  FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 183                                                           statements                                  FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 184                                            PT FKS FOOD SEJAHTERA TBK               2              2   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 185                                                              Tanggal              31           2024   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 186                                                   Desember (Diaudit)              31           2023   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 187                                              (Disajikan dalam jutaan                                  FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 188                                                                   As              31            202   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 189                                                   December (Audited)              31           2023   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 190                                                           (Expressed                                  FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 191                                                              Maret /              31             31   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 192                                                             Catatan/              31             31   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 193                                                                Notes                           2023   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 194                                                          Utang usaha              14             14   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 195                                                         Pihak ketiga                         151291   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 196                                                       Pihak berelasi               6          25070   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 197                                 Beban akrual dan provisi provision s              15         166953   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 198                                                          Utang pajak              9c          36034   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 199                                            jangka pendek liabilities              42          32500   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 200                                             Utang bank jangka pendek             17a          93573   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 201                                                           Utang bank             17b             17   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 202                                                      Liabilitas sewa              16          21350   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 203                                                       pendek lainnya              8b          71809   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 204                                                  non-usaha non-trade               6          82898   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 205                                                   Liabilitas kontrak               3           3987   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 206                                                               Jangka                         659907   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 207                                            Utang bank jangka panjang                                  FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 208                                                    setelah dikurangi                                  FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 209                                                        bagian lancar             17b          69048   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 210                                                      Liabilitas sewa                                  FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 211                                                    setelah dikurangi                                  FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 212                                                    bagian lancar net              16          35343   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 213                                    Liabilitas pajak tangguhan - neto              9e          51242   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 214                           Liabilitas imbalan pasca kerja liabilities              18          65897   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 215                                                               Jangka                         221899   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 216                                                                                              881806
# 217                                                                  are                                  FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 218                                                        konsolidasian                                  FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 219                                                           statements                                  FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 220                                            PT FKS FOOD SEJAHTERA TBK               3              3   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 221                                                              Tanggal              31           2024   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 222                                                   Desember (Diaudit)              31           2023   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 223                                              (Disajikan dalam jutaan                                  FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 224                                                                   As              31            202   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 225                                                   December (Audited)              31           2023   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 226                                                           (Expressed                                  FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 227                                                              Maret /              31             31   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 228                                                             Catatan/              31             31   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 229                                                                Notes                           2023   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 230                                                        Saham seri A:                            500   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 231                                                        Saham seri B:                            200   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 232                                                        Saham seri A:                      135000000   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 233                                                         saham shares              18    18662500000   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 234                                                        Saham seri A:                      135000000   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 235                                                        Saham seri B:               9     9176800000   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 236                                                       saham shares :              19        1902860   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 237                                        Tambahan modal disetor - neto              20        1515597   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 238                                        Penghasilan komprehensif lain              21         502316   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 239                                                            Defisit )               2       (2960347   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 240                                                                                              969551
# 241                                                          Kepentingan               1             0)   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 242                                                                                              968198
# 243                                                                                    1        1850004
# 244                                                                  are                                  FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 245                                                        konsolidasian                                  FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 246                                                           statements                                  FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 247                                                                                    4              4
# 248                                    Untuk periode (tiga) bulanan yang               3              3   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 249                                                              tanggal              30           2024   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 250                                              (Disajikan dalam jutaan                                  FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 251                                  For the (three) months period ended               3              3   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 252                                                          March and (              31           2024   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 253                                                           (Expressed                                  FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 254                                                       bulan / months               3              3   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 255                                                                Notes                           2023   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 256                                                       Penjualan neto              22             22   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 257                                            Beban pokok penjualan ) )              23             23   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 258                                                           Laba bruto                         134136   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 259                                     Beban penjualan dan distribusi )              88             24   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 260                                      Beban umum dan administrasi ) )              55             25   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 261                                                  Penghasilan lainnya               1             26   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 262                                                      Beban lainnya )               4             27   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 263                                                           Laba usaha              27          13513   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 264                                                 Penghasilan keuangan              28             28   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 265                                                   Beban keuangan ) )               6             29   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 266                                                    pajak penghasilan              21              4   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 267                                              Beban pajak penghasilan              9d              9   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 268                                                  Laba tahun berjalan              10           2101   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 269                                   program imbalan pasti benefit plan               3             18   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 270                   kembali program imbalan pasti defined benefit plan               9              9   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 271                                                 Revaluasi aset tetap               2              9   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 272                                     lain tahun berjalan for the year               4           2158   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 273                                   tahun berjalan income for the year              15           4259   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 274                                                Pemilik entitas induk              10           2099   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 275                                            Kepentingan nonpengendali               4              2   FKS Food Sejahtera TBK_billingual_31 Maret 2024.pdf
# 276                                                                                   10           2101
# 277                                                   MARET DAN DESEMBER              31           2024                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 278                                     YANG BERAKHIR PADA TANGGAL MARET              31           2024                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 279                                                 MARET (TIDAK DIUDIT)              31          2023)                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 280                                                   MARCH AND DECEMBER              31           2024                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 281                                                   PERIOD ENDED MARCH              31           2024                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 282                                                    MARCH (UNAUDITED)              31            202                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 283                                                                  are                                                      Lapkeu ABBA 31 Mar 2024 (1).pdf
# 284                                                   MARET DAN DESEMBER              31           2024                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 285                                     PADA TANGGAL MARET (DENGAN ANGKA              31           2024                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 286                                    PADA TANGGAL MARET (TIDAK DIUDIT)              31          2023)                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 287                                                   MARCH AND DECEMBER              31            202                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 288                                      MARCH (WITH COMPARATIVE FIGURES              31            202                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 289                                                    MARCH (UNAUDITED)              31            202                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 290                                                              Laporan               1              1                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 291                                                         Komprehensif               4                                      Lapkeu ABBA 31 Mar 2024 (1).pdf
# 292                                                              Laporan               5              5                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 293                                                              Laporan               6                                      Lapkeu ABBA 31 Mar 2024 (1).pdf
# 294                                                              Catatan               7              7                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 295                                                                  are                                                      Lapkeu ABBA 31 Mar 2024 (1).pdf
# 296                                           TANGGAL MARET DAN DESEMBER              31           2024                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 297                                                     (Disajikan dalam                                                      Lapkeu ABBA 31 Mar 2024 (1).pdf
# 298                                                                   AS              31           2024                       Lapkeu ABBA 31 Mar 2024 (1).pdf
# 299                                                           (Expressed                                                      Lapkeu ABBA 31 Mar 2024 (1).pdf
# ...
# 438                                                              Laporan               8              9  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 439                                                         Catatan atas              10             91  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 440                                                                   in                                 LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 441                                            MARET (TIDAK DIAUDIT) DAN              31           2024  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 442                                       DESEMBER MARCH (UNAUDITED) AND              31           2023  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 443                                                             DECEMBER              31           2023  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 444                                                     (Disajikan dalam                                 LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 445                                                   secara keseluruhan                                 LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 446                                                          Halaman - -               1             31  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 447                                                                March                           2024  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 448                                                                Notes              31             31  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 449                                                             December                           2023  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 450                                                   Kas dan setara kas          2a, 2b              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 451                                                Pihak ketiga – bersih          2a, 2d              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 452                                                         Pihak ketiga       2a, 2d, 6              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 453                                                      Portofolio efek       2a, 2j, 8              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 454                                                           Persediaan       2a, 2g, 7              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 455                                                        dan uang muka       2a, 2f, 9              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 456                                                 LANCAR TOTAL CURRENT              74    26783474495  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 457                                                               ASSETS              00             00  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 458                                                       Pihak berelasi          2a, 2d              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 459                                                         Pihak ketiga              16       28164545  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 460                                                      Aset lain -lain          2a, 10              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 461                                                  Aset tetap – bersih          2a, 2h              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 462                                                 Aset pajak tangguhan           2a, 2              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 463                                      TIDAK LANCAR TOTAL NON -CURRENT              82    80146601751  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 464                                             JUMLAH ASET TOTAL ASSETS                   106930076246  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 465                                                                   in                                 LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 466                                            MARET (TIDAK DIAUDIT) DAN              31           2024  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 467                                       DESEMBER MARCH (UNAUDITED) AND              31           2023  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 468                                                             DECEMBER              31           2023  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 469                                                     (Disajikan dalam                                 LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 470                                                   secara keseluruhan                                 LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 471                                                          Halaman - -               2              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 472                                                               Maret/              31             31  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 473                                                                March                           2024  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 474                                                                Notes              31             31  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 475                                                                                                2023
# 476                                                         Pihak ketiga       2a, 2k, 1              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 477                                                  Uang muka pelanggan      2a, 2l, 13              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 478                                                              dibayar      2a, 2l, 14              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 479                                                           Utang bank           2a, 1              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 480                                                          Utang pajak           2a, 2              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 481                                          JANGKA PENDEK TOTAL CURRENT              23    47891113389  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 482                                             Liabilitas imbalan kerja       2a, 2m, 1              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 483                                    JANGKA PANJANG TOTAL NON -CURRENT               2     2359093653  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 484                                  JUMLAH LIABILITAS TOTAL LIABILITIES              26    50250207042  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 485                                                                 seri              20             20  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 486                                                            per saham               6    55378870020  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 487                                              Share capital – nominal              18    41502310020  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 488                                                               series              20             20  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 489                                                            per share               6              6  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 490                                               Tambahan modal disetor              63             19  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 491                                                           Saldo laba               9              0  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 492                                                        penggunaannya              20             20  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 493                                                        penggunaannya               2     4756771798  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 494                                               komprehensif lainnya )                     (212237951  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 495                                                         JUMLAH EKUIT              56    56679869204  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 496                                                            DAN EKUIT                   106930076246  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 497                                                                   in                                 LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 498                      MARET DAN (TIDAK DIAUDIT) MARCH AND (UNAUDITED)              31           2024  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 499                                                     (Disajikan dalam                                 LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 500                                                   secara keseluruhan                                 LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 501                                                          Halaman - -               3              3  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 502                                                               Maret/              31             31  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 503                                                             Catatan/                           2024  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 504                                                               Maret/              31             31  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 505                                                                                                2023
# 506                                                            PENJUALAN  2a, 2e, 2l, 21              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 507                                                            PENJUALAN           2a, 2              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 508                                              LABA KOTOR GROSS PROFIT               6     3636580875  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 509                                                             dan umum           2a, 2              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 510                                                       selisih kurs )          2a, 2l              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 511                                                  operasional lainnya  2a, 2e, 2l, 24              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 512                                                          terealisasi              16              9  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 513                                                                    a           2a, 8                 LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 514                                               Unrealized gain (loss)              16              9  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 515                                                  operasional lainnya          2a, 2l              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 516                                             LABA OPERASI INCOME FROM               3     2446724043  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 517                                                  Pendapatan keuangan           2a, 2              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 518                                                     Beban keuangan )           2a, 2              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 519                                            PENGHASILAN INCOME BEFORE               3     1989123739  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 520                                                     penghasilan kini  2a, 2l, 2n,16B              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 521                                                            tangguhan          2a, 2n              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 522                                                                    c             16c       32052869  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 523                                      TAHUN BERJALAN CURRENT YEAR NET               2     1069405568  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 524                                                                   in                                 LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 525                      MARET DAN (TIDAK DIAUDIT) MARCH AND (UNAUDITED)              31           2024  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 526                                                     (Disajikan dalam                                 LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 527                                                   secara keseluruhan                                 LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 528                                                          Halaman - -               4              4  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 529                                                               Maret/              31             31  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 530                                                                March                           2024  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 531                                                               Maret/              31             31  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 532                                                                March                           2023  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 533                                      TAHUN BERJALAN CURRENT YEAR NET               2     1069405568  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 534                                                                pasti       2a, 2m, 1              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 535                                                                pasti       2a, 2n, 1              2  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 536                                                  LAIN – BERSIH OTHER              27     -101482728  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 537                                         TAHUN BERJALAN TOTAL CURRENT               2      967922840  LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf
# 538                                                       LABA PER SAHAM          2r, 27                 LKA PT Samcro Hyosung Adilestari Tbk Maret 2024_.pdf

# %% [markdown]
# <h2><b>ESKTRAK IDENTIFIER</b></h2>

# %%
# Daftar bulan untuk pencocokan
bulan_list_id = [
    "Januari", "Februari", "Maret", "April", "Mei", "Juni",
    "Juli", "Agustus", "September", "Oktober", "November", "Desember"
]

bulan_list_en = [
    "January", "February", "March", "April", "May", "June",
    "July", "August", "September", "October", "November", "December"
]

# Fungsi untuk membaca teks dari file PDF
def extract_text_from_pdf(pdf_path):
    with pdfplumber.open(pdf_path) as pdf:
        # Ambil teks dari halaman pertama
        first_page = pdf.pages[0]
        text = first_page.extract_text()
    return text

# Fungsi untuk mengekstrak nama perusahaan dan bulan/tahun dari teks PDF
def find_company_and_month_year(text):
    # Pencocokan nama perusahaan yang dimulai dengan "PT" dan mengandung "Tbk" atau variasinya
    company_pattern = re.compile(r"(PT\s[\w\s]+,\s?Tbk|PT\s[\w\s]+Tbk)", re.IGNORECASE)
    company_match = company_pattern.search(text)
    
    # Pencocokan bulan dan tahun (baik bahasa Indonesia maupun Inggris)
    months_years = []
    for bulan in bulan_list_id + bulan_list_en:  # Menggabungkan bulan dalam bahasa Indonesia dan Inggris
        # Regex untuk menemukan bulan dan tahun setelahnya
        pattern = re.compile(rf"(\b{bulan}\b)\s(\d{{4}})", re.IGNORECASE)
        
        # Cari kecocokan dengan pola regex
        matches = pattern.findall(text)
        
        for match in matches:
            month, year = match
            months_years.append((month.strip(), int(year)))  # Simpan bulan dan tahun sebagai tuple

    # Menyimpan nama perusahaan dan bulan/tahun yang ditemukan
    company_name = company_match.group(1) if company_match else "Tidak ditemukan"
    
    return company_name, months_years

# Fungsi untuk mendapatkan bulan dan tahun terbaru dari list bulan/tahun
def get_latest_month_and_year(months_years):
    # Jika tidak ada bulan atau tahun yang ditemukan
    if not months_years:
        return None, None
    
    # Menemukan tahun terbesar dan bulan yang sesuai dengan tahun tersebut
    latest_year = max(months_years, key=lambda x: x[1])[1]  # Ambil tahun terbesar
    latest_month = next(month for month, year in months_years if year == latest_year)  # Ambil bulan yang sesuai dengan tahun terbesar
    
    return latest_month, latest_year

# Fungsi untuk mengonversi bulan menjadi kuartal
def convert_month_to_quarter(month):
    # Normalisasi nama bulan
    month = month.strip().capitalize()
    
    q1 = ["Januari", "February", "Maret", "March"]
    q2 = ["April", "Mei", "May", "Juni", "June"]
    q3 = ["Juli", "July", "Agustus", "August", "September"]
    q4 = ["Oktober", "October", "November", "Desember", "December"]
    
    if month in q1:
        return "Kuartal I/First Quarter"
    elif month in q2:
        return "Kuartal II/Second Quarter"
    elif month in q3:
        return "Kuartal III/Third Quarter"
    elif month in q4:
        return "Tahunan/Annual"
    else:
        return "Unknown"

# Fungsi untuk memproses banyak file PDF dalam folder dan menghasilkan DataFrame
def extract_data_from_folder(folder_path):
    data = []
    
    # Loop untuk memproses setiap file PDF dalam folder
    for filename in os.listdir(folder_path):
        if filename.endswith('.pdf'):
            pdf_path = os.path.join(folder_path, filename)
            text = extract_text_from_pdf(pdf_path)
            
            # Temukan nama perusahaan dan bulan/tahun dari teks
            company_name, months_years = find_company_and_month_year(text)
            
            # Ambil bulan dan tahun terbaru
            latest_month, latest_year = get_latest_month_and_year(months_years)
            
            # Konversi bulan menjadi kuartal
            if latest_month and latest_year:
                quarter = convert_month_to_quarter(latest_month)
                data.append([company_name, quarter, latest_year, filename])  # Tambahkan nama file sebagai Source_File
    
    # Membuat DataFrame dari hasil ekstraksi
    df = pd.DataFrame(data, columns=["Nama Perusahaan", "Kuartal", "Tahun", "Source_File"])
    return df

# Ganti dengan path folder yang berisi file PDF
folder_path = "C:/TI-Dwika/Semester 7/Pangkalan Data/file_pdf"

# Ekstrak data dari folder dan tampilkan DataFrame
df_info = extract_data_from_folder(folder_path)
print(df_info)
# Out:
#                     Nama Perusahaan                    Kuartal  Tahun  \
# 0       PT ASIA SEJAHTERA MINA, Tbk  Kuartal II/Second Quarter   2024
# 1         PT FKS Food Sejahtera Tbk    Kuartal I/First Quarter   2024
# 2             PT ACSET INDONUSA Tbk  Kuartal II/Second Quarter   2024
# 3               PT MAHAKA MEDIA TBK    Kuartal I/First Quarter   2024
# 4  PT SAMCRO HYOSUNG ADILESTARI TBK    Kuartal I/First Quarter   2024
#
#                                          Source_File
# 0                          AGAR TW 2 KONSOL 2024.pdf
# 1  FKS Food Sejahtera TBK billingual 31 Maret 202...
# 2             FS PT Acset Indonusa Tbk Juni 2024.pdf
# 3                        Lapkeu ABBA 31 Mar 2024.pdf
# 4  LKA PT Samcro Hyosung Adilestari Tbk Maret 202...

# %%
# Fungsi untuk menggabungkan df_data dan df_file_info
# Gabungkan kedua DataFrame berdasarkan 'Source_File' yang menyimpan nama file PDF
merged_df = pd.merge(df_info, df_data, on='Source_File', how='left')

# Menghapus kolom 'Source_File' dari DataFrame yang telah digabungkan
merged_df = merged_df.drop(columns=['Source_File'])

merged_df

# %%
import os
import re
import time
import pandas as pd
from PyPDF2 import PdfReader
from sqlalchemy import create_engine
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler


# Daftar bulan untuk pencocokan
bulan_list_id = [
    "Januari", "Februari", "Maret", "April", "Mei", "Juni",
    "Juli", "Agustus", "September", "Oktober", "November", "Desember"
]

bulan_list_en = [
    "January", "February", "March", "April", "May", "June",
    "July", "August", "September", "October", "November", "December"
]


def extract_text_from_pdf(pdf_path, start_page=1, end_page=None):
    try:
        reader = PdfReader(pdf_path)
        text_content = ""
        total_pages = len(reader.pages)

        # Adjust end_page if it's not provided or exceeds total pages
        if end_page is None or end_page > total_pages:
            end_page = total_pages

        # Extract text from the specified page range
        for page_num in range(start_page - 1, end_page):
            page = reader.pages[page_num]
            text_content += page.extract_text() + "\n"
        return text_content
    except Exception as e:
        print(f"Error reading PDF {pdf_path}: {str(e)}")
        return None


def extract_table_data(text_content, filename):
    # Split content into lines
    lines = text_content.split('\n')

    # Initialize lists to store extracted data
    items = []
    values = []
    notes = []
    file_sources = []  # To track which file each row came from

    # Regular expressions for matching
    number_pattern = r'\(?[\d,.]+\)?'  # Matches numbers with 6 or more digits

    # First notes pattern: Matches patterns like 2f, 2v, or 2v,2g
    notes_pattern_1 = r'\d+[a-zA-Z](?:,\s?[a-zA-Z\d]+)*'  # Matches patterns like 2v, 2g, 3f, or 2v,2g

    # Second notes pattern: Matches just numbers (like 22)
    notes_pattern_2 = r'\b\d{1,2}(?:,\s?\d{1,2})*\b'

    for line in lines:
        # Clean the line
        line = line.strip()

        # Try to identify components
        number_match = re.search(number_pattern, line)
        notes_match_1 = re.search(notes_pattern_1, line)
        notes_match_2 = re.search(notes_pattern_2, line)

        if number_match:
            # Extract the item name by removing numbers and notes
            item = re.sub(number_pattern, '', line)  # Remove numbers from item
            item = re.sub(notes_pattern_1, '', item)  # Remove notes from item
            item = re.sub(notes_pattern_2, '', item)  # Remove additional notes
            item = re.sub(r'\s+', ' ', item).strip()  # Replace multiple spaces with a single space

            # Remove empty parentheses and remaining text after them
            item = re.sub(r'\(\s*\).*', '', item).strip()

            # Remove single or double letters and all remaining text after them
            item = re.sub(r'\s[a-zA-Z]{1,2}\s.*', '', item).strip()

            # # Remove remaining words if they start with an uppercase letter
            # item = re.sub(r'\s[A-Z][a-zA-Z]*.*', '', item).strip()

            # Remove remaining words if they start with an uppercase letter, but not all caps
            item = re.sub(r'\s([A-Z][a-z][a-zA-Z]*)\b.*', '', item).strip()

            numbers = re.findall(number_pattern, line)
            if len(numbers) > 1:
                # General case: pick the second number, or use any logic to decide which number to take
                value = numbers[1]  # Take the second number (can be adjusted)
            elif len(numbers) == 1:
                value = numbers[0]
            else:
                # If no numbers found, return an empty string
                value = " "

            # Extract value
            # value = number_match.group()
            
            # Use the first notes pattern if it matches (allows comma-separated notes)
            if notes_match_1:
                note = notes_match_1.group()
            # Only use the second notes pattern if the first one didn't match
            elif notes_match_2 and not notes_match_1:
                note = notes_match_2.group()
            else:
                note = "" 

            # Directly append to lists without any additional condition
            values.append(value)
            notes.append(note)

            # Only include if we have all components and it's not a total
            if item and not item.lower().startswith('total'):
                items.append(item)
                file_sources.append(filename) 

            # Ensure lists remain the same length by filling any missing values
            while len(items) < len(values):
                items.append("")
            while len(notes) < len(values):
                notes.append("")
            while len(file_sources) < len(values):
                file_sources.append("")

    # Create DataFrame
    df = pd.DataFrame({
        'Item': items,
        'Notes': notes,
        'Value': values,
        'Source_File': file_sources
    })
    
    return df

def find_company_and_month_year(text):
    # Company name pattern
    company_pattern = re.compile(r"(PT\s[\w\s]+,\s?Tbk|PT\s[\w\s]+Tbk)", re.IGNORECASE)
    company_match = company_pattern.search(text)
    
    # Month and year matching
    months_years = []
    for bulan in bulan_list_id + bulan_list_en:
        pattern = re.compile(rf"(\b{bulan}\b)\s(\d{{4}})", re.IGNORECASE)
        
        # Find matches with regex pattern
        matches = pattern.findall(text)
        
        for match in matches:
            month, year = match
            months_years.append((month.strip(), int(year)))

    # Get company name
    company_name = company_match.group(1) if company_match else "Tidak ditemukan"
    
    return company_name, months_years

def get_latest_month_and_year(months_years):
    """
    Get the latest month and year from the list
    """
    if not months_years:
        return None, None
    
    latest_year = max(months_years, key=lambda x: x[1])[1]
    latest_month = next(month for month, year in months_years if year == latest_year)
    
    return latest_month, latest_year

def convert_month_to_quarter(month):
    # Normalize month name
    month = month.strip().capitalize()
    
    q1 = ["Januari", "February", "Maret", "March"]
    q2 = ["April", "Mei", "May", "Juni", "June"]
    q3 = ["Juli", "July", "Agustus", "August", "September"]
    q4 = ["Oktober", "October", "November", "Desember", "December"]
    
    if month in q1:
        return "Kuartal I/First Quarter"
    elif month in q2:
        return "Kuartal II/Second Quarter"
    elif month in q3:
        return "Kuartal III/Third Quarter"
    elif month in q4:
        return "Tahunan/Annual"
    else:
        return "Unknown"

def filter_dataframe(df):
    if df is None:
        return None
    
    # Function to check if a value is valid
    def is_valid_value(value):
        # Convert to string to handle various input types
        str_value = str(value).strip()
        
        unwanted_patterns = [
            r'^[\.]+$',  # hanya dots
            r'^2024$',   # hanya 2024
            r'^2023$',   # hanya 2023
            r'^[\.]{5,}$'  # 5 atau lebih dots
        ]
        
        # Check if value matches any unwanted pattern
        for pattern in unwanted_patterns:
            if re.match(pattern, str_value):
                return False
        
        # Check if value has at least 5 digits
        digit_count = len(re.findall(r'\d', str_value))
        
        return digit_count >= 1
    
    # Filter the DataFrame
    filtered_df = df[df['Value'].apply(is_valid_value)]
    
    # Print out how many rows were removed
    original_rows = len(df)
    filtered_rows = len(filtered_df)
    removed_rows = original_rows - filtered_rows
    print(f"Filtered out {removed_rows} rows (from {original_rows} to {filtered_rows} rows)")
    
    return filtered_df

def process_pdf_folder(folder_path, start_page=1, end_page=8):
    # Lists to store DataFrames
    table_dfs = []
    info_dfs = []

    # Get all PDF files in the folder
    pdf_files = [f for f in os.listdir(folder_path) if f.lower().endswith('.pdf')]

    if not pdf_files:
        print(f"No PDF files found in {folder_path}")
        return None

    # Process each PDF file
    for pdf_file in pdf_files:
        print(f"Processing {pdf_file}...")
        pdf_path = os.path.join(folder_path, pdf_file)

        # Extract text from PDF
        text_content = extract_text_from_pdf(pdf_path, start_page, end_page)

        if text_content:
            # Process table data
            table_df = extract_table_data(text_content, pdf_file)
            if not table_df.empty:
                table_dfs.append(table_df)
            
            # Process file info
            company_name, months_years = find_company_and_month_year(text_content)
            latest_month, latest_year = get_latest_month_and_year(months_years)
            
            if latest_month and latest_year:
                quarter = convert_month_to_quarter(latest_month)
                info_df = pd.DataFrame({
                    'Nama Perusahaan': [company_name],
                    'Kuartal': [quarter],
                    'Tahun': [latest_year],
                    'Source_File': [pdf_file]
                })
                info_dfs.append(info_df)

    # Combine DataFrames
    if table_dfs and info_dfs:
        combined_table_df = pd.concat(table_dfs, ignore_index=True)
        combined_info_df = pd.concat(info_dfs, ignore_index=True)
        
        # Merge the two DataFrames
        merged_pdf = pd.merge(combined_info_df, combined_table_df, on='Source_File', how='left')
        
        # Drop the Source_File column
        merged_pdf = merged_pdf.drop(columns=['Source_File'])
        
        # Filter the merged DataFrame
        filtered_pdf = filter_dataframe(merged_pdf)
        
        return filtered_pdf
    else:
        print("No data was extracted from any PDF files")
        return None

def get_merged_pdf_data(folder_path):
    merged_pdf = process_pdf_folder(folder_path)
    
    if merged_pdf is not None:
        print("\nMerged and Filtered PDF Data:")
        print(merged_pdf)
        return merged_pdf
    else:
        print("Tidak ada data yang berhasil diekstrak.")
        return None


def export_to_mysql(merged_df, table_name='tb_pdf', 
                    mysql_user='root', 
                    mysql_password='Dika007!#', 
                    mysql_host='localhost', 
                    mysql_port='3306', 
                    db_name='db_calk'):
    try:
        # Rename columns to match database schema
        column_mapping = {
            'Nama Perusahaan': 'nama_perusahaan_pdf',
            'Kuartal': 'kuartal_pdf',
            'Tahun': 'tahun_pdf',
            'Item': 'item_pdf',
            'Notes': 'notes_pdf',
            'Value': 'value_pdf',
        }
        
        # Rename columns using the mapping
        merged_df = merged_df.rename(columns=column_mapping)
        # Create SQLAlchemy engine
        engine = create_engine(f'mysql+pymysql://{mysql_user}:{mysql_password}@{mysql_host}:{mysql_port}/{db_name}')
        # Export DataFrame to MySQL
        merged_df.to_sql(table_name, con=engine, if_exists='append', index=False)
        
        print(f"\nData successfully exported to MySQL database '{db_name}', table '{table_name}'.")
    except Exception as e:
        print(f"Error exporting to MySQL: {e}")


# Kelas untuk menangani event file baru
class MyHandler(FileSystemEventHandler):
    def __init__(self, folder_path):
        self.folder_path = folder_path

    def on_created(self, event):
        if event.is_directory:
            return  # Skip folder
        if event.src_path.lower().endswith('.pdf'): 
            processed_file = event.src_path + '.processed'
            if not os.path.exists(processed_file):
                print(f"\nFile baru ditemukan: {event.src_path}")
                process_and_export(event.src_path)
            else:
                print(f"File {event.src_path} sudah diproses sebelumnya, melewatkan...")

# Fungsi untuk memproses dan mengekspor data dari file PDF
def process_and_export(pdf_path):
    # Mengambil data dari PDF
    merged_pdf = get_merged_pdf_data(pdf_path)
    
    if merged_pdf is not None:
        # Export ke MySQL
        export_to_mysql(
            merged_pdf,
            table_name='tb_pdf', 
            mysql_user='root', 
            mysql_password='Dika007!#', 
            db_name='db_calk' 
        )
        # Tandai file sudah diproses
        processed_file = pdf_path + '.processed'
        with open(processed_file, 'w') as f:
            f.write('Processed') 
        print(f"File {pdf_path} berhasil diproses dan diekspor ke database.")
    else:
        print(f"Gagal memproses file {pdf_path}")

# Fungsi untuk memproses semua file yang sudah ada
def process_existing_files(folder_path):
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        if file_path.lower().endswith('.pdf'): 
            processed_file = file_path + '.processed'
            if not os.path.exists(processed_file): 
                print(f"\nMemproses file yang sudah ada: {file_path}")
                process_and_export(file_path)
            else:
                print(f"File {file_path} sudah diproses sebelumnya, melewatkan...")

# Membuat observer untuk memantau folder
def start_monitoring(folder_path):
    event_handler = MyHandler(folder_path)
    observer = Observer()
    observer.schedule(event_handler, folder_path, recursive=False)
    
    # Proses file yang sudah ada di folder
    process_existing_files(folder_path)
    
    # Mulai memantau folder
    observer.start()
    print(f"Memantau folder: {folder_path} untuk file baru...")

    try:
        while True:
            time.sleep(1)
    except KeyboardInterrupt:
        observer.stop()
        print("\nPemantauan dihentikan.")
    observer.join()

# Main function
if __name__ == "__main__":
    folder_path = 'C:/TI-Dwika/Semester 7/Pangkalan Data/file_pdf'
    start_monitoring(folder_path)

# %%
merged_df.info()

# %%
import os
import re
import time
import pandas as pd
from PyPDF2 import PdfReader
from sqlalchemy import create_engine
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler


# Daftar bulan untuk pencocokan
bulan_list_id = [
    "Januari", "Februari", "Maret", "April", "Mei", "Juni",
    "Juli", "Agustus", "September", "Oktober", "November", "Desember"
]

bulan_list_en = [
    "January", "February", "March", "April", "May", "June",
    "July", "August", "September", "October", "November", "December"
]


def extract_text_from_pdf(pdf_path, start_page=1, end_page=None):
    try:
        reader = PdfReader(pdf_path)
        text_content = ""
        total_pages = len(reader.pages)

        # Adjust end_page if it's not provided or exceeds total pages
        if end_page is None or end_page > total_pages:
            end_page = total_pages

        # Extract text from the specified page range
        for page_num in range(start_page - 1, end_page):
            page = reader.pages[page_num]
            text_content += page.extract_text() + "\n"
        return text_content
    except Exception as e:
        print(f"Error reading PDF {pdf_path}: {str(e)}")
        return None


def extract_table_data(text_content, filename):
    # Split content into lines
    lines = text_content.split('\n')

    # Initialize lists to store extracted data
    items = []
    values = []
    notes = []
    file_sources = []  # To track which file each row came from

    # Regular expressions for matching
    number_pattern = r'\(?[\d,.]+\)?'  # Matches numbers with 6 or more digits

    # First notes pattern
    notes_pattern_1 = r'\d+[a-zA-Z](?:,\s?[a-zA-Z\d]+)*' 

    # Second notes pattern
    notes_pattern_2 = r'\b\d{1,2}(?:,\s?\d{1,2})*\b'

    for line in lines:
        # Clean the line
        line = line.strip()

        # Try to identify components
        number_match = re.search(number_pattern, line)
        notes_match_1 = re.search(notes_pattern_1, line)
        notes_match_2 = re.search(notes_pattern_2, line)

        if number_match:
            # Extract the item name by removing numbers and notes
            item = re.sub(number_pattern, '', line)  
            item = re.sub(notes_pattern_1, '', item)  
            item = re.sub(notes_pattern_2, '', item) 
            item = re.sub(r'\s+', ' ', item).strip() 

            # Remove empty parentheses and remaining text after them
            item = re.sub(r'\(\s*\).*', '', item).strip()

            # Remove single or double letters and all remaining text after them
            item = re.sub(r'\s[a-zA-Z]{1,2}\s.*', '', item).strip()

            # # Remove remaining words if they start with an uppercase letter
            # item = re.sub(r'\s[A-Z][a-zA-Z]*.*', '', item).strip()

            # Remove remaining words if they start with an uppercase letter, but not all caps
            item = re.sub(r'\s([A-Z][a-z][a-zA-Z]*)\b.*', '', item).strip()

            numbers = re.findall(number_pattern, line)
            if len(numbers) > 1:
                # General case: pick the second number, or use any logic to decide which number to take
                value = numbers[1]
            elif len(numbers) == 1:
                value = numbers[0]
            else:
                # If no numbers found, return an empty string
                value = " "

            # Extract value
            # value = number_match.group()
            
            # Use the first notes pattern if it matches (allows comma-separated notes)
            if notes_match_1:
                note = notes_match_1.group()
            # Only use the second notes pattern if the first one didn't match
            elif notes_match_2 and not notes_match_1:
                note = notes_match_2.group()
            else:
                note = ""  # Default case if no notes are found

            # Modify values: remove commas, periods, and handle parentheses for negative values
            if value.startswith('(') and value.endswith(')') or value.startswith('('):
                # Remove parentheses, then make it negative
                value = '-' + value[1:-1].replace('.', '').replace(',', '')
            else:
                # Just remove commas and periods
                value = value.replace('.', '').replace(',', '')

            
            # Directly append to lists without any additional condition
            values.append(value)
            notes.append(note)

            # Only include if we have all components and it's not a total
            if item and not item.lower().startswith('total'):
                items.append(item)
                file_sources.append(filename)  # Add filename to track source

            # Ensure lists remain the same length by filling any missing values
            while len(items) < len(values):
                items.append("")
            while len(notes) < len(values):
                notes.append("")
            while len(file_sources) < len(values):
                file_sources.append("")

    # Create DataFrame
    df = pd.DataFrame({
        'Item': items,
        'Notes': notes,
        'Value': values,
        'Source_File': file_sources
    })
    
    return df


def find_company_and_month_year(text):
    # Company name pattern
    company_pattern = re.compile(r"(PT\s[\w\s]+,\s?Tbk|PT\s[\w\s]+Tbk)", re.IGNORECASE)
    company_match = company_pattern.search(text)
    
    # Month and year matching
    months_years = []
    for bulan in bulan_list_id + bulan_list_en:
        pattern = re.compile(rf"(\b{bulan}\b)\s(\d{{4}})", re.IGNORECASE)
        
        # Find matches with regex pattern
        matches = pattern.findall(text)
        
        for match in matches:
            month, year = match
            months_years.append((month.strip(), int(year)))

    # Get company name
    company_name = company_match.group(1) if company_match else "Tidak ditemukan"
    
    return company_name, months_years


def get_latest_month_and_year(months_years):
    if not months_years:
        return None, None
    
    latest_year = max(months_years, key=lambda x: x[1])[1]
    latest_month = next(month for month, year in months_years if year == latest_year)
    
    return latest_month, latest_year


def convert_month_to_quarter(month):
    # Normalize month name
    month = month.strip().capitalize()
    
    q1 = ["Januari", "February", "Maret", "March"]
    q2 = ["April", "Mei", "May", "Juni", "June"]
    q3 = ["Juli", "July", "Agustus", "August", "September"]
    q4 = ["Oktober", "October", "November", "Desember", "December"]
    
    if month in q1:
        return "Kuartal I / First Quarter"
    elif month in q2:
        return "Kuartal II / Second Quarter"
    elif month in q3:
        return "Kuartal III / Third Quarter"
    elif month in q4:
        return "Tahunan / Annual"
    else:
        return "Unknown"


def filter_dataframe(df):
    if df is None:
        return None
    
    # Function to check if a value is valid
    def is_valid_value(value):
        # Convert to string to handle various input types
        str_value = str(value).strip()
        
        unwanted_patterns = [
            r'^[\.]+$',  # hanya dots
            r'^2024$',   # hanya 2024
            r'^2023$',   # hanya 2023
            r'^[\.]{5,}$'  # 5 atau lebih dots
        ]
        
        # Check if value matches any unwanted pattern
        for pattern in unwanted_patterns:
            if re.match(pattern, str_value):
                return False
        
        # Check if value has at least 1 digits
        digit_count = len(re.findall(r'\d', str_value))
        
        return digit_count >= 1
    
    # Filter the DataFrame
    filtered_df = df[df['Value'].apply(is_valid_value)]
    
    # Print out how many rows were removed
    original_rows = len(df)
    filtered_rows = len(filtered_df)
    removed_rows = original_rows - filtered_rows
    print(f"Filtered out {removed_rows} rows (from {original_rows} to {filtered_rows} rows)")
    
    return filtered_df


def process_pdf_folder(folder_path, start_page=1, end_page=8):
    # Lists to store DataFrames
    table_dfs = []
    info_dfs = []

    # Normalize the folder path to use os.path methods
    folder_path = os.path.normpath(folder_path)

    # Get all PDF files in the folder
    pdf_files = [f for f in os.listdir(folder_path) if f.lower().endswith('.pdf')]

    if not pdf_files:
        print(f"No PDF files found in {folder_path}")
        return None

    # Process each PDF file
    for pdf_file in pdf_files:
        print(f"Processing {pdf_file}...")
        # Use os.path.join to create the full file path
        pdf_path = os.path.join(folder_path, pdf_file)

        # Extract text from PDF
        text_content = extract_text_from_pdf(pdf_path, start_page, end_page)

        if text_content:
            # Process table data
            table_df = extract_table_data(text_content, pdf_file)
            if not table_df.empty:
                table_dfs.append(table_df)
            
            # Process file info
            company_name, months_years = find_company_and_month_year(text_content)
            latest_month, latest_year = get_latest_month_and_year(months_years)
            
            if latest_month and latest_year:
                quarter = convert_month_to_quarter(latest_month)
                info_df = pd.DataFrame({
                    'Nama Perusahaan': [company_name],
                    'Kuartal': [quarter],
                    'Tahun': [latest_year],
                    'Source_File': [pdf_file]
                })
                info_dfs.append(info_df)

    # Combine DataFrames
    if table_dfs and info_dfs:
        combined_table_df = pd.concat(table_dfs, ignore_index=True)
        combined_info_df = pd.concat(info_dfs, ignore_index=True)
        
        # Merge the two DataFrames
        merged_pdf = pd.merge(combined_info_df, combined_table_df, on='Source_File', how='left')
        
        # Drop the Source_File column
        merged_pdf = merged_pdf.drop(columns=['Source_File'])
        merged_pdf['Nama Perusahaan'] = merged_pdf['Nama Perusahaan'].str.upper().str.replace(', TBK', 'TBK')
        # Filter the merged DataFrame
        filtered_pdf = filter_dataframe(merged_pdf)
        
        return filtered_pdf
    else:
        print("No data was extracted from any PDF files")
        return None


def get_merged_pdf_data(folder_path):
    merged_pdf = process_pdf_folder(folder_path)
    
    if merged_pdf is not None:
        print("\nMerged and Filtered PDF Data:")
        print(merged_pdf)
        return merged_pdf
    else:
        print("Tidak ada data yang berhasil diekstrak.")
        return None


def export_to_mysql(merged_df, table_name='tb_pdf', 
                    mysql_user='root', 
                    mysql_password='Dika007!#', 
                    mysql_host='localhost', 
                    mysql_port='3306', 
                    db_name='db_calk'):
    try:
        # Rename columns to match database schema
        column_mapping = {
            'Nama Perusahaan': 'nama_perusahaan_pdf',
            'Kuartal': 'kuartal_pdf',
            'Tahun': 'tahun_pdf',
            'Item': 'item_pdf',
            'Notes': 'notes_pdf',
            'Value': 'value_pdf',
        }
        
        # Rename columns using the mapping
        merged_df = merged_df.rename(columns=column_mapping)
        # Create SQLAlchemy engine
        engine = create_engine(f'mysql+pymysql://{mysql_user}:{mysql_password}@{mysql_host}:{mysql_port}/{db_name}')
        # Export DataFrame to MySQL
        merged_df.to_sql(table_name, con=engine, if_exists='append', index=False)
        
        print(f"\nData successfully exported to MySQL database '{db_name}', table '{table_name}'.")
    except Exception as e:
        print(f"Error exporting to MySQL: {e}")


# Kelas untuk menangani event file baru
class MyHandler(FileSystemEventHandler):
    def __init__(self, folder_path):
        self.folder_path = os.path.normpath(folder_path)

    def on_created(self, event):
        if event.is_directory:
            return  # Skip folder
        
        # Normalize the file path
        event_src_path = os.path.normpath(event.src_path)
        
        if event_src_path.lower().endswith('.pdf'): 
            processed_file = event_src_path + '.processed'
            if not os.path.exists(processed_file):
                print(f"\nFile baru ditemukan: {event_src_path}")
                process_and_export(event_src_path)
            else:
                print(f"File {event_src_path} sudah diproses sebelumnya, melewatkan...")


# Fungsi untuk memproses dan mengekspor data dari file PDF
def process_and_export(pdf_path):
    # Pastikan pdf_path dinormalisasi
    pdf_path = os.path.normpath(pdf_path)
    
    # Ambil direktori dari pdf_path
    pdf_folder = os.path.dirname(pdf_path)
    
    # Mengambil data dari PDF
    merged_pdf = get_merged_pdf_data(pdf_folder)
    
    if merged_pdf is not None:
        # Export ke MySQL
        export_to_mysql(
            merged_pdf,
            table_name='tb_pdf', 
            mysql_user='root', 
            mysql_password='Dika007!#', 
            db_name='db_calk' 
        )
        # Tandai file sudah diproses
        processed_file = pdf_path + '.processed'
        with open(processed_file, 'w') as f:
            f.write('Processed') 
        print(f"File {pdf_path} berhasil diproses dan diekspor ke database.")
    else:
        print(f"Gagal memproses file {pdf_path}")


# Fungsi untuk memproses semua file yang sudah ada
def process_existing_files(folder_path):
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        if file_path.lower().endswith('.pdf'): 
            processed_file = file_path + '.processed'
            if not os.path.exists(processed_file): 
                print(f"\nMemproses file yang sudah ada: {file_path}")
                process_and_export(file_path)
            else:
                print(f"File {file_path} sudah diproses sebelumnya, melewatkan...")

# Membuat observer untuk memantau folder
def start_monitoring(folder_path):
    event_handler = MyHandler(folder_path)
    observer = Observer()
    observer.schedule(event_handler, folder_path, recursive=False)
    
    # Proses file yang sudah ada di folder
    process_existing_files(folder_path)
    
    # Mulai memantau folder
    observer.start()
    print(f"Memantau folder: {folder_path} untuk file baru...")

    try:
        while True:
            time.sleep(1)
    except KeyboardInterrupt:
        observer.stop()
        print("\nPemantauan dihentikan.")
    observer.join()

# Main function
if __name__ == "__main__":
    folder_path = 'C:/TI-Dwika/Semester 7/Pangkalan Data/file_pdf'
    start_monitoring(folder_path)
# Out:
# Memproses file yang sudah ada: C:/TI-Dwika/Semester 7/Pangkalan Data/file_pdf\AGAR TW 2 KONSOL 2024.pdf
# Processing AGAR TW 2 KONSOL 2024.pdf...
# Processing FKS Food Sejahtera TBK billingual 31 Maret 2024.pdf...
# Processing Lapkeu ABBA 31 Mar 2024.pdf...
# Processing LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf...
# Filtered out 172 rows (from 512 to 340 rows)
#
# Merged and Filtered PDF Data:
#                       Nama Perusahaan                    Kuartal  Tahun  \
# 2          PT ASIA SEJAHTERA MINA TBK  Kuartal I / First Quarter   2024
# 7          PT ASIA SEJAHTERA MINA TBK  Kuartal I / First Quarter   2024
# 8          PT ASIA SEJAHTERA MINA TBK  Kuartal I / First Quarter   2024
# 9          PT ASIA SEJAHTERA MINA TBK  Kuartal I / First Quarter   2024
# 10         PT ASIA SEJAHTERA MINA TBK  Kuartal I / First Quarter   2024
# ..                                ...                        ...    ...
# 506  PT SAMCRO HYOSUNG ADILESTARI TBK  Kuartal I / First Quarter   2024
# 507  PT SAMCRO HYOSUNG ADILESTARI TBK  Kuartal I / First Quarter   2024
# 508  PT SAMCRO HYOSUNG ADILESTARI TBK  Kuartal I / First Quarter   2024
# 509  PT SAMCRO HYOSUNG ADILESTARI TBK  Kuartal I / First Quarter   2024
# 510  PT SAMCRO HYOSUNG ADILESTARI TBK  Kuartal I / First Quarter   2024
#
#                                 Item      Notes       Value
# 2                               JUNE         30         202
# 7         the six month period ended         30         202
# 8                                and          3           3
# 9                        Kompehensif          3           3
# 10                           Laporan          4           4
# ..                               ...        ...         ...
# 506  TAHUN BERJALAN CURRENT YEAR NET          2  1069405568
# 507                            pasti  2a, 2m, 1           2
# 508                            pasti  2a, 2n, 1           2
# 509              LAIN – BERSIH OTHER         27  -101482728
# 510     TAHUN BERJALAN TOTAL CURRENT          2   967922840
#
# [340 rows x 6 columns]
#
# Data successfully exported to MySQL database 'db_calk', table 'tb_pdf'.
# File C:\TI-Dwika\Semester 7\Pangkalan Data\file_pdf\AGAR TW 2 KONSOL 2024.pdf berhasil diproses dan diekspor ke database.
#
# Memproses file yang sudah ada: C:/TI-Dwika/Semester 7/Pangkalan Data/file_pdf\FKS Food Sejahtera TBK billingual 31 Maret 2024.pdf
# Processing AGAR TW 2 KONSOL 2024.pdf...
# Processing FKS Food Sejahtera TBK billingual 31 Maret 2024.pdf...
# Processing Lapkeu ABBA 31 Mar 2024.pdf...
# Processing LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf...
# Filtered out 172 rows (from 512 to 340 rows)
#
# Merged and Filtered PDF Data:
#                       Nama Perusahaan                    Kuartal  Tahun  \
# 2          PT ASIA SEJAHTERA MINA TBK  Kuartal I / First Quarter   2024
# 7          PT ASIA SEJAHTERA MINA TBK  Kuartal I / First Quarter   2024
# 8          PT ASIA SEJAHTERA MINA TBK  Kuartal I / First Quarter   2024
# 9          PT ASIA SEJAHTERA MINA TBK  Kuartal I / First Quarter   2024
# 10         PT ASIA SEJAHTERA MINA TBK  Kuartal I / First Quarter   2024
# ..                                ...                        ...    ...
# 506  PT SAMCRO HYOSUNG ADILESTARI TBK  Kuartal I / First Quarter   2024
# 507  PT SAMCRO HYOSUNG ADILESTARI TBK  Kuartal I / First Quarter   2024
# 508  PT SAMCRO HYOSUNG ADILESTARI TBK  Kuartal I / First Quarter   2024
# 509  PT SAMCRO HYOSUNG ADILESTARI TBK  Kuartal I / First Quarter   2024
# 510  PT SAMCRO HYOSUNG ADILESTARI TBK  Kuartal I / First Quarter   2024
#
#                                 Item      Notes       Value
# 2                               JUNE         30         202
# 7         the six month period ended         30         202
# 8                                and          3           3
# 9                        Kompehensif          3           3
# 10                           Laporan          4           4
# ..                               ...        ...         ...
# 506  TAHUN BERJALAN CURRENT YEAR NET          2  1069405568
# 507                            pasti  2a, 2m, 1           2
# 508                            pasti  2a, 2n, 1           2
# 509              LAIN – BERSIH OTHER         27  -101482728
# 510     TAHUN BERJALAN TOTAL CURRENT          2   967922840
#
# [340 rows x 6 columns]
#
# Data successfully exported to MySQL database 'db_calk', table 'tb_pdf'.
# File C:\TI-Dwika\Semester 7\Pangkalan Data\file_pdf\FKS Food Sejahtera TBK billingual 31 Maret 2024.pdf berhasil diproses dan diekspor ke database.
#
# Memproses file yang sudah ada: C:/TI-Dwika/Semester 7/Pangkalan Data/file_pdf\Lapkeu ABBA 31 Mar 2024.pdf
# Processing AGAR TW 2 KONSOL 2024.pdf...
# Processing FKS Food Sejahtera TBK billingual 31 Maret 2024.pdf...
# Processing Lapkeu ABBA 31 Mar 2024.pdf...
# Processing LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf...
# Filtered out 172 rows (from 512 to 340 rows)
#
# Merged and Filtered PDF Data:
#                       Nama Perusahaan                    Kuartal  Tahun  \
# 2          PT ASIA SEJAHTERA MINA TBK  Kuartal I / First Quarter   2024
# 7          PT ASIA SEJAHTERA MINA TBK  Kuartal I / First Quarter   2024
# 8          PT ASIA SEJAHTERA MINA TBK  Kuartal I / First Quarter   2024
# 9          PT ASIA SEJAHTERA MINA TBK  Kuartal I / First Quarter   2024
# 10         PT ASIA SEJAHTERA MINA TBK  Kuartal I / First Quarter   2024
# ..                                ...                        ...    ...
# 506  PT SAMCRO HYOSUNG ADILESTARI TBK  Kuartal I / First Quarter   2024
# 507  PT SAMCRO HYOSUNG ADILESTARI TBK  Kuartal I / First Quarter   2024
# 508  PT SAMCRO HYOSUNG ADILESTARI TBK  Kuartal I / First Quarter   2024
# 509  PT SAMCRO HYOSUNG ADILESTARI TBK  Kuartal I / First Quarter   2024
# 510  PT SAMCRO HYOSUNG ADILESTARI TBK  Kuartal I / First Quarter   2024
#
#                                 Item      Notes       Value
# 2                               JUNE         30         202
# 7         the six month period ended         30         202
# 8                                and          3           3
# 9                        Kompehensif          3           3
# 10                           Laporan          4           4
# ..                               ...        ...         ...
# 506  TAHUN BERJALAN CURRENT YEAR NET          2  1069405568
# 507                            pasti  2a, 2m, 1           2
# 508                            pasti  2a, 2n, 1           2
# 509              LAIN – BERSIH OTHER         27  -101482728
# 510     TAHUN BERJALAN TOTAL CURRENT          2   967922840
#
# [340 rows x 6 columns]
#
# Data successfully exported to MySQL database 'db_calk', table 'tb_pdf'.
# File C:\TI-Dwika\Semester 7\Pangkalan Data\file_pdf\Lapkeu ABBA 31 Mar 2024.pdf berhasil diproses dan diekspor ke database.
#
# Memproses file yang sudah ada: C:/TI-Dwika/Semester 7/Pangkalan Data/file_pdf\LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf
# Processing AGAR TW 2 KONSOL 2024.pdf...
# Processing FKS Food Sejahtera TBK billingual 31 Maret 2024.pdf...
# Processing Lapkeu ABBA 31 Mar 2024.pdf...
# Processing LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf...
# Filtered out 172 rows (from 512 to 340 rows)
#
# Merged and Filtered PDF Data:
#                       Nama Perusahaan                    Kuartal  Tahun  \
# 2          PT ASIA SEJAHTERA MINA TBK  Kuartal I / First Quarter   2024
# 7          PT ASIA SEJAHTERA MINA TBK  Kuartal I / First Quarter   2024
# 8          PT ASIA SEJAHTERA MINA TBK  Kuartal I / First Quarter   2024
# 9          PT ASIA SEJAHTERA MINA TBK  Kuartal I / First Quarter   2024
# 10         PT ASIA SEJAHTERA MINA TBK  Kuartal I / First Quarter   2024
# ..                                ...                        ...    ...
# 506  PT SAMCRO HYOSUNG ADILESTARI TBK  Kuartal I / First Quarter   2024
# 507  PT SAMCRO HYOSUNG ADILESTARI TBK  Kuartal I / First Quarter   2024
# 508  PT SAMCRO HYOSUNG ADILESTARI TBK  Kuartal I / First Quarter   2024
# 509  PT SAMCRO HYOSUNG ADILESTARI TBK  Kuartal I / First Quarter   2024
# 510  PT SAMCRO HYOSUNG ADILESTARI TBK  Kuartal I / First Quarter   2024
#
#                                 Item      Notes       Value
# 2                               JUNE         30         202
# 7         the six month period ended         30         202
# 8                                and          3           3
# 9                        Kompehensif          3           3
# 10                           Laporan          4           4
# ..                               ...        ...         ...
# 506  TAHUN BERJALAN CURRENT YEAR NET          2  1069405568
# 507                            pasti  2a, 2m, 1           2
# 508                            pasti  2a, 2n, 1           2
# 509              LAIN – BERSIH OTHER         27  -101482728
# 510     TAHUN BERJALAN TOTAL CURRENT          2   967922840
#
# [340 rows x 6 columns]
#
# Data successfully exported to MySQL database 'db_calk', table 'tb_pdf'.
# File C:\TI-Dwika\Semester 7\Pangkalan Data\file_pdf\LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf berhasil diproses dan diekspor ke database.
# Memantau folder: C:/TI-Dwika/Semester 7/Pangkalan Data/file_pdf untuk file baru...
#
# Pemantauan dihentikan.
