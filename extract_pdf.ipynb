# %%
import os
import re
import time
import pandas as pd
import pdfplumber
from PyPDF2 import PdfReader
from tabulate import tabulate
from sqlalchemy import create_engine
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler

# %%
# Daftar bulan untuk pencocokan
bulan_list_id = [
    "Januari", "Februari", "Maret", "April", "Mei", "Juni",
    "Juli", "Agustus", "September", "Oktober", "November", "Desember"
]

bulan_list_en = [
    "January", "February", "March", "April", "May", "June",
    "July", "August", "September", "October", "November", "December"
]

# Fungsi mengambil teks dari halaman atau indeks pertama file pdf
def extract_first_pages_pdf(pdf_path):
    with pdfplumber.open(pdf_path) as pdf:
        # Mengambil teks dari halaman pertama
        first_page = pdf.pages[0]
        text = first_page.extract_text()
    return text


# Fungsi mengambil teks dari halaman 1 file pdf
def extract_text_from_pages(pdf_path, start_page=1, end_page=None):
    try:
        reader = PdfReader(pdf_path)
        text_content = ""
        total_pages = len(reader.pages)

        if end_page is None or end_page > total_pages:
            end_page = total_pages

        # Mengekstrak teks dari halaman yang ditentukan
        for page_num in range(start_page - 1, end_page):
            page = reader.pages[page_num]
            text_content += page.extract_text() + "\n"
        return text_content
    except Exception as e:
        print(f"Error reading PDF {pdf_path}: {str(e)}")
        return None


# Fungsi untuk mengekstrak tabel
def extract_table_data(text_content, filename):
    # Membagi konten menjadi baris
    lines = text_content.split('\n')

    # Inisialisasi list untuk menyimpan hasil ekstraksi
    items = []
    values = []
    notes = []
    file_sources = []

    # Regular expression
    # Untuk mengekstrak angka
    number_pattern = r'\(?[\d,.]+\)?' 

    # Mengekstrak pattern note (2v,2b  18, 5c)
    notes_pattern_1 = r'\d+[a-zA-Z](?:,\s?[a-zA-Z\d]+)*' 

    # Mengekstrak pattern note alternatif (23,25  29)
    notes_pattern_2 = r'\b\d{1,2}(?:,\s?\d{1,2})*\b'

    for line in lines:
        line = line.strip()

        # Mengindentifikasi komponen
        number_match = re.search(number_pattern, line)
        notes_match_1 = re.search(notes_pattern_1, line)
        notes_match_2 = re.search(notes_pattern_2, line)

        if number_match:
            # Mengekstrak 'item' dan menghilangkan 'numbers' dan 'notes' dari item
            item = re.sub(number_pattern, '', line)  
            item = re.sub(notes_pattern_1, '', item)  
            item = re.sub(notes_pattern_2, '', item) 
            item = re.sub(r'\s+', ' ', item).strip() 

            # Menghilangkan tanda kurung kosong () dan teks setelahnya
            item = re.sub(r'\(\s*\).*', '', item).strip()

            # Menghilangkan huruf tunggal atau ganda (v  fv) dan teks setelahnya
            item = re.sub(r'\s[a-zA-Z]{1,2}\s.*', '', item).strip()

            # Menghilangkan teks setelahnya apabila dimulai dengan huruf besar (bukan semua kapital)
            # item = re.sub(r'\s([A-Z][a-z][a-zA-Z]*)\b.*', '', item).strip()

            # Mengekstrak value berdasarkan 'number_pattern'
            numbers = re.findall(number_pattern, line)
            if len(numbers) > 1:
                value = numbers[1]
            elif len(numbers) == 1:
                value = numbers[0]
            else:
                value = " "

            # Menggunakan notes_pattern 1 jika sesuai
            if notes_match_1:
                note = notes_match_1.group()
            # Hanya menggunakan notes_patern 2 jika notes_pattern 1 tidak sesuai
            elif notes_match_2 and not notes_match_1:
                note = notes_match_2.group()
            else:
                note = ""  # Default case if no notes are found

            # Modifikasi values
            if value.startswith('(') and value.endswith(')') or value.startswith('('):
                # Mengubah tanda dalam kurung menjadi negatif
                value = '-' + value[1:-1].replace('.', '').replace(',', '')
            else:
                # Menghilangkan tanda . dan ,
                value = value.replace('.', '').replace(',', '')

            
            # Append value dan note ke masing-masing list
            values.append(value)
            notes.append(note)

            # Hanya menyertakan semua komponen dan tidak dimulai dengan 'total'
            if item and not item.lower().startswith('total'):
                items.append(item)
                file_sources.append(filename)  # Add filename to track source

            # Memastikan list memiliki panjang yang sama
            while len(items) < len(values):
                items.append("")
            while len(notes) < len(values):
                notes.append("")
            while len(file_sources) < len(values):
                file_sources.append("")

    # Membuat dataframe
    df = pd.DataFrame({
        'Item': items,
        'Notes': notes,
        'Value': values,
        'Source_File': file_sources
    })
    
    return df


# Fungsi mencari nama perusahaan, bulan, dan tahun
def find_company_and_month_year(text):
    # Pattern nama perusahaan
    company_pattern = re.compile(r"(PT\s[\w\s]+,\s?Tbk|PT\s[\w\s]+Tbk)", re.IGNORECASE)
    company_match = company_pattern.search(text)
    
    # Mencocokkan bulan dan tahun
    months_years = []
    for bulan in bulan_list_id + bulan_list_en:
        pattern = re.compile(rf"(\b{bulan}\b)\s(\d{{4}})", re.IGNORECASE)
        
        # Mencari kecocokan dengan pattern regex
        matches = pattern.findall(text)
        
        for match in matches:
            month, year = match
            months_years.append((month.strip(), int(year)))

    # Mengekstrak nama perusahaan
    company_name = company_match.group(1) if company_match else "Tidak ditemukan"
    
    return company_name, months_years


# Fungsi mendapatkan bulan dan tahun terakhir
def get_latest_month_and_year(months_years):
    if not months_years:
        return None, None
    # Tahun terakhir
    latest_year = max(months_years, key=lambda x: x[1])[1]
    # Bulan terakhir
    latest_month = next(month for month, year in months_years if year == latest_year)
    
    return latest_month, latest_year


# Fungsi mengkonversi bulan menjadi kuartal
def convert_month_to_quarter(month):
    # Normalisasi nama bulan
    month = month.strip().capitalize()
    
    # List tiap kuartal
    q1 = ["Januari", "January", "Februari", "February", "Maret", "March"]
    q2 = ["April", "Mei", "May", "Juni", "June"]
    q3 = ["Juli", "July", "Agustus", "August", "September"]
    q4 = ["Oktober", "October", "November", "Desember", "December"]
    
    # Kondisi kuartal
    if month in q1:
        return "Kuartal I / First Quarter"
    elif month in q2:
        return "Kuartal II / Second Quarter"
    elif month in q3:
        return "Kuartal III / Third Quarter"
    elif month in q4:
        return "Tahunan / Annual"
    else:
        return "Unknown"


# Fungsi filer dataframe
def filter_dataframe(df):
    if df is None:
        return None
    
    # Fungsi untuk mengecek apakah value valid
    def is_valid_value(value):
        # Konversi value ke tipe string
        str_value = str(value).strip()
        
        # Pattern yang ingin dihilangkan
        unwanted_patterns = [
            r'^[\.]+$',  # hanya dot
            r'^2024$',   # hanya 2024
            r'^2023$',   # hanya 2023
            r'^[\.]{5,}$'  # 5 atau lebih dot
        ]
        
        # Mengecek apakah value sesuai atau cocok dengan unwanted_patterns
        for pattern in unwanted_patterns:
            if re.match(pattern, str_value):
                return False
        
        # Mengecek apakah value terdiri dari minimal 1 digit
        digit_count = len(re.findall(r'\d', str_value))
        
        return digit_count >= 1
    
    # Filter dataframe
    filtered_df = df[df['Value'].apply(is_valid_value)]
    
    # Print banyak baris yang dihilangkan
    original_rows = len(df)
    filtered_rows = len(filtered_df)
    removed_rows = original_rows - filtered_rows
    print(f"Filtered out {removed_rows} rows (from {original_rows} to {filtered_rows} rows)")
    
    return filtered_df


# Fungsi untuk memproses folder
def process_pdf_folder(folder_path, table_start_page=1, table_end_page=8):
    table_dfs = []
    info_dfs = []
    # Mengambil path dari folder
    folder_path = os.path.normpath(folder_path)
    # Menentukan file dengan format .pdf
    pdf_files = [f for f in os.listdir(folder_path) if f.lower().endswith('.pdf')]

    if not pdf_files:
        print(f"No PDF files found in {folder_path}")
        return None

    for pdf_file in pdf_files:
        print(f"Processing {pdf_file}...")
        pdf_path = os.path.join(folder_path, pdf_file)

        # Ekstrak teks dari halaman pertama untuk nama perusahaan dan kuartal
        first_page_text = extract_first_pages_pdf(pdf_path)
        if first_page_text:
            company_name, months_years = find_company_and_month_year(first_page_text)
            latest_month, latest_year = get_latest_month_and_year(months_years)

            if latest_month and latest_year:
                quarter = convert_month_to_quarter(latest_month)
                info_df = pd.DataFrame({
                    'Nama Perusahaan': [company_name],
                    'Kuartal': [quarter],
                    'Tahun': [latest_year],
                    'Source_File': [pdf_file]
                })
                info_dfs.append(info_df)

        # Ekstrak teks dari halaman 1–8 untuk tabel
        table_text = extract_text_from_pages(pdf_path, table_start_page, table_end_page)
        if table_text:
            table_df = extract_table_data(table_text, pdf_file)
            if not table_df.empty:
                table_dfs.append(table_df)

    # Menggabungkan dataframe
    if table_dfs and info_dfs:
        combined_table_df = pd.concat(table_dfs, ignore_index=True)
        combined_info_df = pd.concat(info_dfs, ignore_index=True)

        # Menggabungkan dataframe berdasarkan kolom Source_File
        merged_pdf = pd.merge(combined_info_df, combined_table_df, on='Source_File', how='left')
        # Drop kolom Source_File
        merged_pdf = merged_pdf.drop(columns=['Source_File'])
        # Menyelaraskan value pada kolom Nama Perusahaan
        merged_pdf['Nama Perusahaan'] = merged_pdf['Nama Perusahaan'].str.upper().str.replace(', TBK', ' TBK')
        # Menghilangkan spasi pada kolom Value
        merged_pdf['Value'] = merged_pdf['Value'].str.replace(' ', '', regex=True)

        filtered_pdf = filter_dataframe(merged_pdf)
        return filtered_pdf
    else:
        print("No data was extracted from any PDF files")
        return None


# Fungsi mendapatkan merged_pdf
def get_merged_pdf_data(folder_path):
    merged_pdf = process_pdf_folder(folder_path)
    
    if merged_pdf is not None:
        print("\nMerged and Filtered PDF Data:")
        print(tabulate(merged_pdf, headers='keys', tablefmt='grid', showindex=False))
        return merged_pdf
    else:
        print("Tidak ada data yang berhasil diekstrak.")
        return None


# Fungsi export dataframe ke database MySQL
def export_to_mysql(merged_df, table_name='tb_pdf', 
                    mysql_user='-', 
                    mysql_password='-', 
                    mysql_host='-', 
                    mysql_port='-', 
                    db_name='-'):
    try:
        # Mapping nama kolom sesuai dengan database
        column_mapping = {
            'Nama Perusahaan': 'nama_perusahaan_pdf',
            'Kuartal': 'kuartal_pdf',
            'Tahun': 'tahun_pdf',
            'Item': 'item_pdf',
            'Notes': 'notes_pdf',
            'Value': 'value_pdf',
        }
        
        # Mengganti nama kolom sesuai mapping
        merged_df = merged_df.rename(columns=column_mapping)
        # SQLAlchemy engine
        engine = create_engine(f'mysql+pymysql://{mysql_user}:{mysql_password}@{mysql_host}:{mysql_port}/{db_name}')
        # Export dataframe ke MySQL
        merged_df.to_sql(table_name, con=engine, if_exists='append', index=False)
        
        print(f"\nData successfully exported to MySQL database '{db_name}', table '{table_name}'.")
    except Exception as e:
        print(f"Error exporting to MySQL: {e}")


# Class untuk menangani event file baru
class MyHandler(FileSystemEventHandler):
    def __init__(self, folder_path):
        self.folder_path = os.path.normpath(folder_path)

    def on_created(self, event):
        if event.is_directory:
            return  # Skip folder
        
        # Normalize the file path
        event_src_path = os.path.normpath(event.src_path)
        
        if event_src_path.lower().endswith('.pdf'): 
            processed_file = event_src_path + '.processed'
            if not os.path.exists(processed_file):
                print(f"\nFile baru ditemukan: {event_src_path}")
                process_and_export(event_src_path)
            else:
                print(f"File {event_src_path} sudah diproses sebelumnya, melewatkan...")


# Fungsi untuk memproses dan mengekspor data dari file PDF
def process_and_export(pdf_path):
    # Normalisasi pdf_path
    pdf_path = os.path.normpath(pdf_path)
    
    # Ambil direktori dari pdf_path
    pdf_folder = os.path.dirname(pdf_path)
    
    # Mengambil data dari PDF
    merged_pdf = get_merged_pdf_data(pdf_folder)
    
    if merged_pdf is not None:
        # Export ke MySQL
        export_to_mysql(
            merged_pdf,
            table_name='tb_pdf', 
            mysql_user='root', 
            mysql_password='Dika007!#', 
            db_name='db_calk' 
        )
        # Tandai file sudah diproses
        processed_file = pdf_path + '.processed'
        with open(processed_file, 'w') as f:
            f.write('Processed') 
        print(f"File {pdf_path} berhasil diproses dan diekspor ke database.")
    else:
        print(f"Gagal memproses file {pdf_path}")


# Fungsi untuk memproses semua file yang sudah ada
def process_existing_files(folder_path):
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        if file_path.lower().endswith('.pdf'): 
            processed_file = file_path + '.processed'
            if not os.path.exists(processed_file): 
                print(f"\nMemproses file yang sudah ada: {file_path}")
                process_and_export(file_path)
            else:
                print(f"File {file_path} sudah diproses sebelumnya, melewatkan...")

# Membuat observer untuk memantau folder
def start_monitoring(folder_path):
    event_handler = MyHandler(folder_path)
    observer = Observer()
    observer.schedule(event_handler, folder_path, recursive=False)
    
    # Proses file yang sudah ada di folder
    process_existing_files(folder_path)
    
    # Mulai memantau folder
    observer.start()
    print(f"Memantau folder: {folder_path} untuk file baru...")

    try:
        while True:
            time.sleep(1)
    except KeyboardInterrupt:
        observer.stop()
        print("\nPemantauan dihentikan.")
    observer.join()

# Main function
if __name__ == "__main__":
    folder_path = 'C:/TI-Dwika/Semester 7/Pangkalan Data/file_pdf'
    start_monitoring(folder_path)
# Out:
# Memproses file yang sudah ada: C:/TI-Dwika/Semester 7/Pangkalan Data/file_pdf\AGAR TW 2 KONSOL 2024.pdf
# Processing AGAR TW 2 KONSOL 2024.pdf...
# Processing FKS Food Sejahtera TBK billingual 31 Maret 2024.pdf...
# Processing Lapkeu ABBA 31 Mar 2024.pdf...
# Processing LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf...
# Filtered out 172 rows (from 512 to 340 rows)
#
# Merged and Filtered PDF Data:
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | Nama Perusahaan                  | Kuartal                     |   Tahun | Item                                                                     | Notes          | Value         |
# +==================================+=============================+=========+==========================================================================+================+===============+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | JUNE                                                                     | 30             | 202           |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | the six month period ended June                                          | 30             | 202           |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | and                                                                      | 3              | 3             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Kompehensif Lain Statement for Profit                                    | 3              | 3             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Laporan Perubahan Ekuitas Statements                                     | 4              | 4             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Laporan Arus Kas Statements                                              | 5              | 5             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Catatan atas Laporan Keuangan Notes                                      | 6              | 6             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | JUNE (UNAUDITED)                                                         | 30             | 202           |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Kas dan setara kas Cash and equivalents                                  | 4              | 14047355680   |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Kas yang                                                                 | 5              | 1900000000    |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | pihak ketiga third parties                                               | 6              | 36522725228   |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Piutang lain-lain Other receivables                                      | 7              | 7             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Pihak ketiga Third parties                                               | 8              | 2500000       |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Persediaan Inventories                                                   | 8              | 78031491296   |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Pajak dibayar dimuka                                                     | 29a            | 1197505340    |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Uang muka pembelian Advance payments                                     | 9              | 11239481729   |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Biaya dibayar                                                            | 10             | 80995607      |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Jumlah Aset Lancar Total Current Assets                                  |                | 143541791622  |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Rp pada Rp                                                               | 21             | 21102003830   |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Rp pada Rp                                                               | 19             | 19956724738   |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Aset lain-lain Other asset                                               | 12             | 2189288648    |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Aset pajak tangguhan                                                     | 29d            | 1071584465    |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Goodwill Goodwill                                                        | 13             | 5321917155    |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Jumlah Aset Tidak Lancar Total Non Current Assets                        | 54             | 53373108248   |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | JUMLAH ASET TOTAL ASSETS                                                 |                | 196914899870  |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Utang usaha Trade account payable                                        | 14             | 14            |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Pihak ketiga Third parties                                               | 13             | 13638407079   |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Utang lain-lain Others payable                                           | 15             | 149264284     |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Beban akrual Accrued expense                                             | 16             | 86238167      |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Uang titipan Deposit payabe                                              | 17             | 1922352000    |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Utang pajak                                                              | 29b            | 149071620     |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Utang bank Bank loan                                                     | 18             | 6095439944    |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | yang jatuh tempo dalam satu tahun lease payables                         | 19             | 62941920635   |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Jumlah Liabilitas Jangka Pendek Total Short Term Liabilities             | 84             | 81650705594   |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | tempo dalam satu tahun current maturities                                | 19             | 6041150918    |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Liabilitas imbalan kerja Employee benefits obligation                    | 20             | 863158842     |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Jumlah Liabilitas Jangka Panjang Total Non-Current Liabilities           | 6              | 8298421520    |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Jumlah Liabilitas Total Liabilities                                      | 91             | 89949127114   |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Rp per lembar saham                                                      |                | 100           |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Modal dasar lembar Authorized shares                                     | 3              | 3000000000    |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | penuh - saham shares                                                     | 1              | 21            |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | pengampunan pajak tax amnesty                                            | 2              | 2000000000    |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Tambahan modal disetor Additional paid-in capital                        | 22             | 3008083551    |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Penghasilan komprehensif lain Other comprehensive income                 | 23             | 899672093     |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Laba Gain                                                                | 1              | 1058036869    |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Jumlah Ekuitas Total Equity                                              |                | 106965792513  |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Kepentingan non-pengendali Non-controlling interest                      | 70             | -19757        |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | JUMLAH EKUITAS TOTAL EQUITY                                              |                | 106965772756  |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | JUMLAH KEWAJIBAN DAN EKUITAS AND EQUITY                                  |                | 196914899870  |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | PADA JUNI DAN (TIDAK DIAUDIT)                                            | 3              | 0             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | PENJUALAN BERSIH NET SALES                                               | 24             | 157707918480  |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | BEBAN POKOK PENJUALAN COST                                               | 25             | -142600768775 |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | LABA KOTOR GROSS PROFIT                                                  | 15             | 19170293134   |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Beban usaha Operating Expense                                            | 26             | -13508791843  |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Pendapatan lain-lain Other income                                        | 27             | 246479816     |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Beban lain-lain Others Expense                                           | 28             | -3071839411   |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | JUMLAH BEBAN USAHA TOTAL OPERATING EXPENSES                              | 16             | -17950375057  |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | PAJAK PENGHASILAN INCOME TAX                                             | 1              | 1219918077    |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | BEBAN PAJAK PENGHASILAN                                                  | 29c            | -13127620     |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | LABA (RUGI) BERSIH NET GAIN (LOSS)                                       | 1              | 895434247     |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | KOMPREHENSIF GAIN (LOSS)                                                 | 1              | 895434247     |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Pemilik entitas induk Owner                                              | 1              | 895458414     |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Kepentingan non pengendali Non-controlling interest                      | 51             | -24167        |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | TAHUN BERJALAN FOR THE YEAR                                              | 1              | 895434247     |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Pemilik entitas induk Owner                                              | 1              | 895458414     |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Kepentingan non pengendali Non-controlling interest                      | 51             | -24167        |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | KOMPREHENSIF TAHUN BERJALAN (LOSS) FOR THE YEAR                          | 1              | 895434247     |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | LABA (LOSS) PER LEMBAR SAHAM GAIN (LOSS) PER SHARE                       | 0              | 072159        |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | dari penerapan PSAK - - - - - - - - PSAK                                 | 24             | 24            |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Laba bersih tahun berjalan - - - - Current year Gain Net Income          | 24             | 895458414     |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | dari penerapan PSAK - - - - - - - - PSAK                                 | 24             | 24            |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Rugi bersih tahun berjalan - - - - Current year Loss Net Income          | 1              | -1240078338   |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | JUNE (UNAUDITED)                                                         | 30             | 202           |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Penerimaan kas dari pelanggan Cash received from customers               |                | 267026244390  |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Cash payments                                                            |                | -264460593050 |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Pembayaran beban usaha operating expenses                                | 13             | -18576402902  |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | pajak penghasilan                                                        | 1              | -395143731    |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Penerimaan (Pembayaraan) lainnya Other received (payment)                |                | 854393809     |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | aktivitas operasi                                                        | 4              | -15551501484  |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Perolehan aset tetap Acquisitions                                        | 1              | -252850385    |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Aset lain-lain - Acquisitions                                            |                | -412046250    |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | aktivitas investasi                                                      | 1              | -664896635    |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | Pembayaran pinjaman bank - Payment                                       | 3              | -3394118809   |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | jangka panjang bank loans                                                | 1              | -1394111760   |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | lembaga keuangan - loans received                                        | 11             | 11955168634   |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | aktivitas investasi activities                                           | 10             | -4788230569   |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | kas dan bank cash and bank                                               | 7              | -21004628688  |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | awal periode beginning                                                   | 6              | 25911737517   |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT ASIA SEJAHTERA MINA TBK       | Kuartal II / Second Quarter |    2024 | pada akhir periode end                                                   | 14             | 4907108829    |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | dan untuk periode (tiga) bulan yang berakhir                             | 3              | 3             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | as                                                                       | 31             | 202           |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | and for the (three) months period ended                                  | 3              | 3             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | DAN UNTUK PERIODE (TIGA) BULAN YANG                                      | 3              | 3             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | AND FOR THE (Three) MONTHS PERIOD ENDED                                  | 3              | 3             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | Laporan Posisi Keuangan Konsolidasian - Consolidated Statement           | 1              | 1             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | Penghasilan Komprehensif Lain Konsolidasian - Other Comprehensive Income | 4              | 4             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | Laporan Perubahan Ekuitas Konsolidasian Consolidated Statement           | 6              | 6             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | Catatan atas Laporan Keuangan Konsolidasian - Notes                      | 8              | 8             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | Desember (Diaudit)                                                       | 31             | 202           |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | Maret / Desember /                                                       | 31             | 31            |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | Catatan/ March December                                                  | 31             | 31            |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | Kas dan setara kas Cash and cash equivalents                             | 4              | 94887         |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | Piutang usaha - neto Trade receivables - net                             | 5              | 5             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | Pihak ketiga Third parties                                               | 17             | 7759          |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | Pihak berelasi Related part ies                                          | 6              | 335769        |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | Aset keuangan lancar lainnya                                             | 8a             | 1912          |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | Persediaan - neto Inventories - net                                      | 7              | 106427        |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | Pajak dibayar                                                            | 9a             | 14488         |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | Biaya dibayar                                                            | 10a            | 7897          |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | lancar lainnya                                                           | 10b            | 22752         |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | Aset tetap - neto Fixed assets - net                                     | 11             | 106600        |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | Properti investasi Investment propert ies                                | 13             | 32193         |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | Goodwill                                                                 | 12a            | 729           |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | Tagihan pajak penghasilan                                                | 9b             | 8848          |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | Aset takberw ujud - neto                                                 | 12b            | 230785        |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | lainnya assets                                                           | 3              | 2351          |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | tidak lancar lainnya financial assets                                    | 51             | 50            |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | PT FKS FOOD SEJAHTERA TBK                                                | 2              | 2             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | As                                                                       | 31             | 202           |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | Maret / Desember/                                                        | 31             | 31            |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | Catatan/ March December                                                  | 31             | 31            |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | Utang usaha Trade payables                                               | 14             | 14            |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | Pihak ketiga Third parties                                               |                | 151291        |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | Pihak berelasi Related parties                                           | 6              | 25070         |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | Beban akrual dan provisi provision s                                     | 15             | 166953        |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | Utang pajak                                                              | 9c             | 36034         |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT FKS FOOD SEJAHTERA TBK        | Kuartal I / First Quarter   |    2024 | jangka pendek liabilities                                                | 42             | 32500         |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# ...
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | JANGKA PANJANG TOTAL NON -CURRENT                                        | 2              | 2359093653    |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | JUMLAH LIABILITAS TOTAL LIABILITIES                                      | 26             | 50250207042   |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | seri                                                                     | 20             | 20            |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | per saham                                                                | 6              | 55378870020   |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | Share capital – nominal                                                  | 18             | 41502310020   |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | series                                                                   | 20             | 20            |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | per share                                                                | 6              | 6             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | Tambahan modal disetor Additional paid                                   | 63             | 19            |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | Saldo laba Retained earnings                                             | 9              | 0             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | penggunaannya Appropriated                                               | 20             | 20            |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | penggunaannya Unappropriated                                             | 2              | 4756771798    |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | komprehensif lainnya ) Other comprehensive                               |                | -21223795     |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | JUMLAH EKUIT                                                             | 56             | 56679869204   |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | DAN EKUIT                                                                |                | 106930076246  |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | Halaman - - Page                                                         | 3              | 3             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | Maret/ March                                                             | 31             | 31            |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | Maret/ March                                                             | 31             | 31            |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | PENJUALAN                                                                | 2a, 2e, 2l, 21 | 2             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | PENJUALAN                                                                | 2a, 2          | 2             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | LABA KOTOR GROSS PROFIT                                                  | 6              | 3636580875    |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | dan umum                                                                 | 2a, 2          | 2             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | selisih kurs )                                                           | 2a, 2l         | 2             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | operasional lainnya                                                      | 2a, 2e, 2l, 24 | 2             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | terealisasi                                                              | 16             | 9             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | Unrealized gain (loss)                                                   | 16             | 9             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | operasional lainnya                                                      | 2a, 2l         | 2             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | LABA OPERASI INCOME FROM                                                 | 3              | 2446724043    |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | Pendapatan keuangan                                                      | 2a, 2          | 2             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | Beban keuangan )                                                         | 2a, 2          | 2             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | PENGHASILAN INCOME BEFORE                                                | 3              | 1989123739    |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | penghasilan kini                                                         | 2a, 2l, 2n,16B | 2             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | tangguhan                                                                | 2a, 2n         | 2             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | c Deferred income tax                                                    | 16c            | 32052869      |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | TAHUN BERJALAN CURRENT YEAR NET                                          | 2              | 1069405568    |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | Halaman - - Page                                                         | 4              | 4             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | Maret/                                                                   | 31             | 31            |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | Maret/                                                                   | 31             | 31            |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | TAHUN BERJALAN CURRENT YEAR NET                                          | 2              | 1069405568    |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | pasti                                                                    | 2a, 2m, 1      | 2             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | pasti                                                                    | 2a, 2n, 1      | 2             |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | LAIN – BERSIH OTHER                                                      | 27             | -101482728    |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
# | PT SAMCRO HYOSUNG ADILESTARI TBK | Kuartal I / First Quarter   |    2024 | TAHUN BERJALAN TOTAL CURRENT                                             | 2              | 967922840     |
# +----------------------------------+-----------------------------+---------+--------------------------------------------------------------------------+----------------+---------------+
#
# Data successfully exported to MySQL database 'db_calk', table 'tb_pdf'.
# File C:\TI-Dwika\Semester 7\Pangkalan Data\file_pdf\LKA PT Samcro Hyosung Adilestari Tbk Maret 2024.pdf berhasil diproses dan diekspor ke database.
# Memantau folder: C:/TI-Dwika/Semester 7/Pangkalan Data/file_pdf untuk file baru...
#
# Pemantauan dihentikan.
